# %% [markdown]
# ## 导包

# %%
import torch
import torch.nn as nn
import os
import numpy as np
import pandas as pd
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision.transforms import ToTensor, Lambda, Compose

# %%
from config import Config
from kits.models import *
from kits.new_models import *
# from kits.models import testmodel
from kits.loss import *
from kits.trainer import BaseModelTrainer, ModelTrainer, parse_data
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import torchmetrics
print(torch.cuda.is_available())
print('1')
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# True
# 1

# %% [markdown]
# ## 数据预处理

# %%
from kits.appDataset import *
import time
import copy

# %% [markdown]
# ## model&参数配置

# %%
config = Config
# 数据读取
data = parse_data(config)

# %%
# 参数设定
config.epoch = 500
config.checkpoint = False
config.lr = 5e-4
config.wd = 1e-4
config.checkpoint = True

# 模型初始化
# config.model_name = "DDDNN"
# model = DDDNN(config, config.device)
# print(model)
config.model_name = "CNN_DD"
model = CNN_DD(config,config.device)
print(model)
# Out:
# CNN_DD(
#   (app_embeddings): Embedding(15752, 128, padding_idx=0)
#   (date_embeddings): Embedding(3551, 128, padding_idx=0)
#   (sep_embeddings): Embedding(3516, 128, padding_idx=0)
#   (cnn_encoder): CNN(
#     (cnn): Sequential(
#       (0): Conv2d(1, 128, kernel_size=(8, 128), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (pool): AdaptiveAvgPool1d(output_size=64)
#     (dnn): Sequential(
#       (0): Linear(in_features=8192, out_features=128, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (cnn_decoder_app): CNN_Decoder(
#     (dnn): Sequential(
#       (0): Linear(in_features=128, out_features=8192, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (upsampling): Upsample(scale_factor=1.890625, mode=linear)
#     (cnn_transpose): Sequential(
#       (0): ConvTranspose2d(128, 1, kernel_size=(8, 128), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (cnn_decoder_time): CNN_Decoder(
#     (dnn): Sequential(
#       (0): Linear(in_features=128, out_features=8192, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (upsampling): Upsample(scale_factor=1.890625, mode=linear)
#     (cnn_transpose): Sequential(
#       (0): ConvTranspose2d(128, 1, kernel_size=(8, 128), stride=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (DecoderBlock): ModuleList(
#     (0): TransformerDecoder(
#       (mutihead_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#       )
#       (ffn): Sequential(
#         (0): Linear(in_features=128, out_features=256, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Dropout(p=0.01, inplace=False)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (layernorm1): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#       (layernorm2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): TransformerDecoder(
#       (mutihead_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#       )
#       (ffn): Sequential(
#         (0): Linear(in_features=128, out_features=256, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Dropout(p=0.01, inplace=False)
#         (3): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (layernorm1): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#       (layernorm2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#     )
#   )
# )

# %%
# trained初始化
framework = BaseModelTrainer(data, config, model)
framework.fit()
# Out:
# savepath/CNN_DD/
# iter_per_epoch 625
# /home/sunyingjie/APP/third_version/kits/loss.py:18: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = F.softmax(input)
# 06:59:20
# Epoch : 91 - loss : 3.0270 - loss_app: 2.7129 - loss_time : 0.3141
# val_loss : 2.9946 - val_loss_app: 2.7329 - val_loss_time : 0.2618
# 07:24:18
# Epoch : 92 - loss : 2.9692 - loss_app: 2.7093 - loss_time : 0.2599
# val_loss : 2.9877 - val_loss_app: 2.7314 - val_loss_time : 0.2563
# 07:48:52
# Epoch : 93 - loss : 2.9619 - loss_app: 2.7074 - loss_time : 0.2545
# val_loss : 2.9761 - val_loss_app: 2.7305 - val_loss_time : 0.2457
# 08:13:23
# Epoch : 94 - loss : 2.9619 - loss_app: 2.7061 - loss_time : 0.2558
# val_loss : 2.9846 - val_loss_app: 2.7265 - val_loss_time : 0.2581
# 08:38:36
# Epoch : 95 - loss : 2.9607 - loss_app: 2.7045 - loss_time : 0.2562
# val_loss : 2.9801 - val_loss_app: 2.7289 - val_loss_time : 0.2512
# 09:02:39
# Epoch : 96 - loss : 2.9567 - loss_app: 2.7028 - loss_time : 0.2540
# val_loss : 2.9749 - val_loss_app: 2.7248 - val_loss_time : 0.2501
# 09:26:54
# Epoch : 97 - loss : 2.9548 - loss_app: 2.7008 - loss_time : 0.2541
# val_loss : 2.9683 - val_loss_app: 2.7238 - val_loss_time : 0.2445
# 09:51:03
# Epoch : 98 - loss : 2.9522 - loss_app: 2.6997 - loss_time : 0.2525
# val_loss : 2.9679 - val_loss_app: 2.7255 - val_loss_time : 0.2424
# 10:15:05
# Epoch : 99 - loss : 2.9551 - loss_app: 2.6982 - loss_time : 0.2569
# val_loss : 2.9790 - val_loss_app: 2.7227 - val_loss_time : 0.2563
# 10:39:37
# Epoch : 100 - loss : 2.9496 - loss_app: 2.6964 - loss_time : 0.2532
# val_loss : 2.9686 - val_loss_app: 2.7201 - val_loss_time : 0.2484
# 11:04:31
# Epoch : 101 - loss : 2.9462 - loss_app: 2.6950 - loss_time : 0.2512
# val_loss : 2.9623 - val_loss_app: 2.7175 - val_loss_time : 0.2448
# 11:29:38
# Epoch : 102 - loss : 2.9459 - loss_app: 2.6936 - loss_time : 0.2523
# val_loss : 2.9751 - val_loss_app: 2.7191 - val_loss_time : 0.2560
# 11:54:45
# Epoch : 103 - loss : 2.9513 - loss_app: 2.6926 - loss_time : 0.2587
# val_loss : 2.9830 - val_loss_app: 2.7185 - val_loss_time : 0.2645
# 12:19:29
# Epoch : 104 - loss : 2.9382 - loss_app: 2.6905 - loss_time : 0.2477
# val_loss : 2.9634 - val_loss_app: 2.7164 - val_loss_time : 0.2470
# 12:44:37
# Epoch : 105 - loss : 2.9393 - loss_app: 2.6898 - loss_time : 0.2496
# val_loss : 2.9592 - val_loss_app: 2.7138 - val_loss_time : 0.2454
# 13:09:05
# Epoch : 106 - loss : 2.9418 - loss_app: 2.6880 - loss_time : 0.2538
# val_loss : 2.9760 - val_loss_app: 2.7153 - val_loss_time : 0.2607
# 13:33:11
# Epoch : 107 - loss : 2.9373 - loss_app: 2.6863 - loss_time : 0.2511
# val_loss : 2.9593 - val_loss_app: 2.7137 - val_loss_time : 0.2455
# 13:56:59
# Epoch : 108 - loss : 2.9302 - loss_app: 2.6849 - loss_time : 0.2453
# val_loss : 2.9497 - val_loss_app: 2.7115 - val_loss_time : 0.2382
# 14:21:09
# Epoch : 109 - loss : 2.9349 - loss_app: 2.6842 - loss_time : 0.2507
# val_loss : 2.9477 - val_loss_app: 2.7099 - val_loss_time : 0.2379
# 14:44:53
# Epoch : 110 - loss : 2.9292 - loss_app: 2.6824 - loss_time : 0.2468
# val_loss : 2.9554 - val_loss_app: 2.7097 - val_loss_time : 0.2457
# 15:08:59
# Epoch : 111 - loss : 2.9317 - loss_app: 2.6820 - loss_time : 0.2497
# val_loss : 2.9605 - val_loss_app: 2.7082 - val_loss_time : 0.2523
# 15:33:39
# Epoch : 112 - loss : 2.9316 - loss_app: 2.6802 - loss_time : 0.2514
# val_loss : 2.9579 - val_loss_app: 2.7076 - val_loss_time : 0.2503
# 15:57:51
# Epoch : 113 - loss : 2.9276 - loss_app: 2.6791 - loss_time : 0.2485
# val_loss : 2.9484 - val_loss_app: 2.7082 - val_loss_time : 0.2402
# early stop!

# %%
from kits.models import *
import torch

from kits.trainer import parse_data
from config import Config

def user_embedding_loop(dataloader, model, device):
    user_embedding_all = torch.tensor([]).to(device)
    y_age_all = torch.tensor([]).to(device)
    y_gender_all = torch.tensor([]).to(device)
    model.eval()
    with torch.no_grad():
        for X, y in dataloader:
            #X = {key:X[key].to(device) for key in X}
            #y = {key:y[key].to(device) for key in y}

            try:
                pred = model(X,None)
            except BaseException: pred = model(X, None)
            
            user_embedding = pred[0] #output=128*len(dataloader) 128 128
            # print('user_embedding',user_embedding.size()) 128，128
            y_age_batch = y['age']
            y_gender_batch = y['gender']
            
            user_embedding_all = torch.cat((user_embedding_all, user_embedding), 0)
            
            y_age_all = torch.cat((y_age_all, y_age_batch), 0)
            y_gender_all = torch.cat((y_gender_all, y_gender_batch), 0)
    # print(user_embedding_all.size())
    # print(y_age_all.size())
    # print(y_gender_all.size())
    # n = 0
    # assert n != 0, 'n is zero!'
    #        80000，128           80000      80000
    return user_embedding_all, y_age_all, y_gender_all


config = Config
#config.length_his=64

#数据读取
data = parse_data(config)

#模型加载
isBaseModel = True
savePath = 'savepath/'
modelName = config.model_name+'/'
if isBaseModel:
    config.has_adapter=False
    model_path = savePath + modelName + 'bestmodel.pt'
else:
    config.has_adapter=True
    model_path = savePath + modelName + '/hyper/age_bestHyperModel.pt'

# Model_dict = {k: v for k, v in Model_dict.items() if k in model.state_dict()}
#读取训练好的权重
# DDNN_lstm
Model_dict = torch.load(model_path)  
# DDNN_lstm_finetune
base_best_model = model 
# print(finetune_model.state_dict())
if 'model_state_dict' in Model_dict:
    Model_dict = Model_dict['model_state_dict']
# for k, v in Model_dict.items():
#     k.replace('DDNN_lstm.','')
Model_dict = {k: v for k, v in Model_dict.items()}
model_dict = base_best_model.state_dict()
model_dict.update(Model_dict)

# 加载参数并拼装base和分类器
base_best_model.load_state_dict(model_dict)
model = base_best_model.to(config.device)
# model = Finetune_model(config, model, config.device)


user_embedding_train, y_age_train, y_gender_train = user_embedding_loop(data[0], model, config.device)
user_embedding_valid, y_age_valid, y_gender_valid = user_embedding_loop(data[1], model, config.device)
user_embedding_test, y_age_test, y_gender_test = user_embedding_loop(data[2], model, config.device)

# torch.save(user_embedding_train, 'finetune_data/DDHCNN/user_embedding_train.pt')
# torch.save(user_embedding_valid, 'finetune_data/DDHCNN/user_embedding_valid.pt')
# torch.save(user_embedding_test, 'finetune_data/DDHCNN/user_embedding_test.pt')
# torch.save(y_age_train, 'finetune_data/DDHCNN/y_age_train.pt')
# torch.save(y_age_valid, 'finetune_data/DDHCNN/y_age_valid.pt')
# torch.save(y_age_test, 'finetune_data/DDHCNN/y_age_test.pt')
# torch.save(y_gender_train, 'finetune_data/DDHCNN/y_gender_train.pt')
# torch.save(y_gender_valid, 'finetune_data/DDHCNN/y_gender_valid.pt')
# torch.save(y_gender_test, 'finetune_data/DDHCNN/y_gender_test.pt')

print('done!')
# Out:
# done!

# %%
device = torch.device('cuda')
device_cpu = torch.device('cpu')
# X_train, y_age_train, y_gender_train = torch.FloatTensor(user_embedding_train), y_age_train, y_gender_train
# X_valid, y_age_valid, y_gender_valid = torch.FloatTensor(user_embedding_valid), y_age_valid, y_gender_valid
# X_test, y_age_test, y_gender_test = torch.FloatTensor(user_embedding_test), y_age_test, y_gender_test 

X_train, y_age_train, y_gender_train= torch.FloatTensor(user_embedding_train.to(device_cpu)).to(device), \
                                      torch.LongTensor(y_age_train.type(torch.LongTensor).to(device_cpu)).to(device), \
                                      torch.LongTensor(y_gender_train.type(torch.LongTensor).to(device_cpu)).to(device)
X_valid, y_age_valid, y_gender_valid = torch.FloatTensor(user_embedding_valid.to(device_cpu)).to(device), \
                                    torch.LongTensor(y_age_valid.type(torch.LongTensor).to(device_cpu)).to(device), \
                                    torch.LongTensor(y_gender_valid.type(torch.LongTensor).to(device_cpu)).to(device)
X_test, y_age_test, y_gender_test = torch.FloatTensor(user_embedding_test.to(device_cpu)).to(device), \
                                    torch.LongTensor(y_age_test.type(torch.LongTensor).to(device_cpu)).to(device), \
                                    torch.LongTensor(y_gender_test.type(torch.LongTensor).to(device_cpu)).to(device)

train_dataset_age = torch.utils.data.TensorDataset(X_train, y_age_train)
valid_dataset_age = torch.utils.data.TensorDataset(X_valid, y_age_valid)
test_dataset_age = torch.utils.data.TensorDataset(X_test, y_age_test)
train_dataset_gender = torch.utils.data.TensorDataset(X_train, y_gender_train)
test_dataset_gender = torch.utils.data.TensorDataset(X_test, y_gender_test)
valid_dataset_gender = torch.utils.data.TensorDataset(X_valid, y_gender_valid)


train_loader_age = torch.utils.data.DataLoader(dataset=train_dataset_age,
                                           batch_size=config.Batch_Size,
                                           shuffle=True)
test_loader_age = torch.utils.data.DataLoader(dataset=test_dataset_age,
                                           batch_size=config.Batch_Size,
                                           shuffle=True)
train_loader_gender = torch.utils.data.DataLoader(dataset=train_dataset_gender,
                                           batch_size=config.Batch_Size,
                                           shuffle=True)
test_loader_gender = torch.utils.data.DataLoader(dataset=test_dataset_gender,
                                           batch_size=config.Batch_Size,
                                           shuffle=True)

valid_loader_gender = torch.utils.data.DataLoader(dataset=valid_dataset_gender,
                                           batch_size=config.Batch_Size,
                                           shuffle=True)
valid_loader_age = torch.utils.data.DataLoader(dataset=valid_dataset_age,
                                           batch_size=config.Batch_Size,
                                           shuffle=True)

# %%
class NeuralNetwork_age(nn.Module):
    def __init__(self):
        super(NeuralNetwork_age, self).__init__()
        self.dnn = nn.Sequential(
            nn.Linear(config.user_dim, config.user_dim//2),
            nn.LeakyReLU(),
            #nn.Dropout(0.2),
            nn.Linear(config.user_dim//2, config.user_dim//4),
            nn.LeakyReLU(),
            #nn.Dropout(0.2),
            nn.Linear(config.user_dim//4, 5),
            nn.Softmax()
        )

    def forward(self, x):
        x = self.dnn(x)
        return x

class NeuralNetwork_gender(nn.Module):
    def __init__(self):
        super(NeuralNetwork_gender, self).__init__()
        self.dnn = nn.Sequential(
            nn.Linear(config.user_dim, config.user_dim//2),
            nn.LeakyReLU(),
            #nn.Dropout(0.2),
            nn.Linear(config.user_dim//2, config.user_dim//4),
            nn.LeakyReLU(),
            #nn.Dropout(0.2),
            nn.Linear(config.user_dim//4, 2),
            nn.Softmax()
        )

    def forward(self, x):
        x = self.dnn(x)
        return x

# %%
def train_loop(dataloader, model, loss_fn, optimizer, epoch):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    epoch_loss = 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss

        
        # print('X',X.size()) #128 128
        # n = 0
        # assert n != 0, 'n is zero!'

        pred = model(X)
        # print('pred',pred.size()) #128 5
        # print('y',y.size())
        loss = loss_fn(pred, y)
        

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss = epoch_loss + (loss.item() / num_batches)

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    return epoch_loss


def test_loop(dataloader, model, loss_fn, num_class):
    test_acc = torchmetrics.Accuracy().to(device)
    test_recall = torchmetrics.Recall(average='none', num_classes=num_class).to(device)
    test_precision = torchmetrics.Precision(average='none', num_classes=num_class).to(device)
    test_auc = torchmetrics.AUROC(average="macro", num_classes=num_class).to(device)

    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    bestValLoss =  float("inf")
    es = 0
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            test_acc(pred.argmax(1), y)
            test_auc.update(pred, y)
            test_recall(pred.argmax(1), y)
            test_precision(pred.argmax(1), y)

    test_loss /= num_batches
    epoch_loss = test_loss
    correct /= size

    total_acc = test_acc.compute()
    total_recall = test_recall.compute()
    total_precision = test_precision.compute()
    total_auc = test_auc.compute()

    #print(f"Test Error: \n Accuracy: {(acc):>8f}, Avg loss: {test_loss:>8f} \n")

    print(f"Test Error: \n Accuracy: {(100 * correct):>0.1f}%, "
          f"Avg loss: {test_loss:>8f}, "
          f"torch metrics acc: {(100 * total_acc):>0.1f}%\n")
    print("recall of every test dataset class: ", total_recall.mean())
    print("precision of every test dataset class: ", total_precision.mean())
    print("auc:", total_auc.item())

    return epoch_loss, correct

# %%
learning_rate = 1e-4
epochs = 500

# %%
model = NeuralNetwork_age().to(device)
print(model)

warmup_epoch = 5
iter_per_epoch = len(train_loader_age)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=0.2, total_iters=20)
# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

cost = []
val = []

best_correct = 0
bestValLoss = float('inf')
es = 0
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    epoch_loss = train_loop(train_loader_age, model, loss_fn, optimizer, t)
    cost.append(epoch_loss)
    epoch_loss, correct = test_loop(valid_loader_age, model, loss_fn, 5)

    scheduler.step()

    val.append(epoch_loss)
    if correct > best_correct:
        best_correct = correct
    #更新状态
    if epoch_loss < bestValLoss:
        bestValLoss = epoch_loss
        es = 0
    else:
    #early stop
        es += 1
        if es > 10:
            print("early stop!")
            break
print(f"Best Accuracy: {(best_correct):>8f}\n")
print("Done!")

plt.plot(np.squeeze(cost),'-r', np.squeeze(val),'-b')
plt.ylabel('age loss')
plt.xlabel('Epoch')
plt.show()

epoch_loss, correct = test_loop(test_loader_age, model, loss_fn, 5)
print(correct)
# Out:
# NeuralNetwork_age(
#   (dnn): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=32, out_features=5, bias=True)
#     (5): Softmax(dim=None)
#   )
# )
# Epoch 1
# -------------------------------
# loss: 1.617667  [    0/80000]
# /home/sunyingjie/anaconda3/envs/pytorch_under11.4/lib/python3.8/site-packages/torch/nn/modules/container.py:204: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# loss: 1.551929  [12800/80000]
# loss: 1.550754  [25600/80000]
# loss: 1.562759  [38400/80000]
# loss: 1.528592  [51200/80000]
# loss: 1.494609  [64000/80000]
# loss: 1.540858  [76800/80000]
# /home/sunyingjie/anaconda3/envs/pytorch_under11.4/lib/python3.8/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Test Error:
#  Accuracy: 37.6%, Avg loss: 1.500119, torch metrics acc: 37.6%
#
# recall of every test dataset class:  tensor(0.2187, device='cuda:0')
# precision of every test dataset class:  tensor(0.3327, device='cuda:0')
# auc: 0.6228651404380798
# Epoch 2
# -------------------------------
# loss: 1.498552  [    0/80000]
# loss: 1.500504  [12800/80000]
# loss: 1.516551  [25600/80000]
# loss: 1.434968  [38400/80000]
# loss: 1.450946  [51200/80000]
# loss: 1.441792  [64000/80000]
# loss: 1.452040  [76800/80000]
# Test Error:
#  Accuracy: 48.3%, Avg loss: 1.432394, torch metrics acc: 48.3%
#
# recall of every test dataset class:  tensor(0.3048, device='cuda:0')
# precision of every test dataset class:  tensor(0.2806, device='cuda:0')
# auc: 0.6837258338928223
# Epoch 3
# -------------------------------
# loss: 1.399648  [    0/80000]
# loss: 1.402338  [12800/80000]
# loss: 1.455230  [25600/80000]
# loss: 1.409227  [38400/80000]
# loss: 1.449331  [51200/80000]
# loss: 1.464001  [64000/80000]
# loss: 1.417134  [76800/80000]
# Test Error:
#  Accuracy: 51.0%, Avg loss: 1.401562, torch metrics acc: 51.0%
#
# recall of every test dataset class:  tensor(0.3315, device='cuda:0')
# precision of every test dataset class:  tensor(0.2993, device='cuda:0')
# auc: 0.6940070986747742
# Epoch 4
# -------------------------------
# loss: 1.374605  [    0/80000]
# loss: 1.406599  [12800/80000]
# loss: 1.387870  [25600/80000]
# loss: 1.397497  [38400/80000]
# loss: 1.418223  [51200/80000]
# loss: 1.417778  [64000/80000]
# loss: 1.408324  [76800/80000]
# Test Error:
#  Accuracy: 53.3%, Avg loss: 1.379004, torch metrics acc: 53.3%
#
# recall of every test dataset class:  tensor(0.3534, device='cuda:0')
# precision of every test dataset class:  tensor(0.3115, device='cuda:0')
# auc: 0.6931371092796326
# Epoch 5
# -------------------------------
# loss: 1.384822  [    0/80000]
# loss: 1.388949  [12800/80000]
# loss: 1.390560  [25600/80000]
# loss: 1.393895  [38400/80000]
# loss: 1.346774  [51200/80000]
# loss: 1.350170  [64000/80000]
# loss: 1.403534  [76800/80000]
# Test Error:
#  Accuracy: 55.0%, Avg loss: 1.363054, torch metrics acc: 55.0%
#
# recall of every test dataset class:  tensor(0.3710, device='cuda:0')
# precision of every test dataset class:  tensor(0.3228, device='cuda:0')
# auc: 0.6912540793418884
# Epoch 6
# -------------------------------
# loss: 1.296426  [    0/80000]
# loss: 1.395387  [12800/80000]
# loss: 1.319147  [25600/80000]
# loss: 1.305862  [38400/80000]
# loss: 1.297373  [51200/80000]
# loss: 1.389572  [64000/80000]
# loss: 1.377910  [76800/80000]
# Test Error:
#  Accuracy: 55.7%, Avg loss: 1.352055, torch metrics acc: 55.7%
#
# recall of every test dataset class:  tensor(0.3785, device='cuda:0')
# precision of every test dataset class:  tensor(0.3284, device='cuda:0')
# auc: 0.693061351776123
# Epoch 7
# -------------------------------
# loss: 1.359235  [    0/80000]
# loss: 1.336736  [12800/80000]
# loss: 1.322621  [25600/80000]
# loss: 1.296036  [38400/80000]
# loss: 1.338049  [51200/80000]
# loss: 1.360922  [64000/80000]
# loss: 1.341822  [76800/80000]
# Test Error:
#  Accuracy: 56.1%, Avg loss: 1.346590, torch metrics acc: 56.1%
#
# recall of every test dataset class:  tensor(0.3828, device='cuda:0')
# precision of every test dataset class:  tensor(0.3339, device='cuda:0')
# auc: 0.6937727332115173
# Epoch 8
# -------------------------------
# loss: 1.391498  [    0/80000]
# loss: 1.350665  [12800/80000]
# loss: 1.358131  [25600/80000]
# loss: 1.376167  [38400/80000]
# loss: 1.392106  [51200/80000]
# loss: 1.359640  [64000/80000]
# loss: 1.280346  [76800/80000]
# Test Error:
#  Accuracy: 56.7%, Avg loss: 1.342116, torch metrics acc: 56.7%
#
# recall of every test dataset class:  tensor(0.3913, device='cuda:0')
# precision of every test dataset class:  tensor(0.3367, device='cuda:0')
# auc: 0.6869496703147888
# Epoch 9
# -------------------------------
# loss: 1.288203  [    0/80000]
# loss: 1.340990  [12800/80000]
# loss: 1.378251  [25600/80000]
# loss: 1.359091  [38400/80000]
# loss: 1.394075  [51200/80000]
# loss: 1.335762  [64000/80000]
# loss: 1.270659  [76800/80000]
# Test Error:
#  Accuracy: 56.8%, Avg loss: 1.335569, torch metrics acc: 56.8%
#
# recall of every test dataset class:  tensor(0.3876, device='cuda:0')
# precision of every test dataset class:  tensor(0.3349, device='cuda:0')
# auc: 0.6936021447181702
# Epoch 10
# -------------------------------
# loss: 1.319945  [    0/80000]
# loss: 1.318022  [12800/80000]
# loss: 1.389829  [25600/80000]
# loss: 1.244992  [38400/80000]
# loss: 1.378694  [51200/80000]
# loss: 1.379616  [64000/80000]
# loss: 1.323414  [76800/80000]
# Test Error:
#  Accuracy: 57.0%, Avg loss: 1.333975, torch metrics acc: 57.0%
#
# recall of every test dataset class:  tensor(0.3937, device='cuda:0')
# precision of every test dataset class:  tensor(0.3396, device='cuda:0')
# auc: 0.6872352361679077
# Epoch 11
# -------------------------------
# loss: 1.318350  [    0/80000]
# loss: 1.336909  [12800/80000]
# loss: 1.333351  [25600/80000]
# loss: 1.401332  [38400/80000]
# loss: 1.323923  [51200/80000]
# loss: 1.285176  [64000/80000]
# loss: 1.310018  [76800/80000]
# Test Error:
#  Accuracy: 57.2%, Avg loss: 1.330942, torch metrics acc: 57.2%
#
# recall of every test dataset class:  tensor(0.3972, device='cuda:0')
# precision of every test dataset class:  tensor(0.3433, device='cuda:0')
# auc: 0.6829724311828613
# Epoch 12
# -------------------------------
# loss: 1.426619  [    0/80000]
# loss: 1.333756  [12800/80000]
# loss: 1.222037  [25600/80000]
# loss: 1.390993  [38400/80000]
# loss: 1.248191  [51200/80000]
# loss: 1.380283  [64000/80000]
# loss: 1.321505  [76800/80000]
# Test Error:
#  Accuracy: 57.1%, Avg loss: 1.328912, torch metrics acc: 57.1%
#
# recall of every test dataset class:  tensor(0.3905, device='cuda:0')
# precision of every test dataset class:  tensor(0.3358, device='cuda:0')
# auc: 0.6936494708061218
# Epoch 13
# -------------------------------
# loss: 1.261416  [    0/80000]
# loss: 1.320438  [12800/80000]
# loss: 1.356630  [25600/80000]
# loss: 1.337893  [38400/80000]
# loss: 1.334177  [51200/80000]
# loss: 1.323757  [64000/80000]
# loss: 1.318249  [76800/80000]
# Test Error:
#  Accuracy: 57.3%, Avg loss: 1.330686, torch metrics acc: 57.3%
#
# recall of every test dataset class:  tensor(0.4004, device='cuda:0')
# precision of every test dataset class:  tensor(0.3454, device='cuda:0')
# auc: 0.6799257397651672
# Epoch 14
# -------------------------------
# loss: 1.303994  [    0/80000]
# loss: 1.311121  [12800/80000]
# loss: 1.358313  [25600/80000]
# loss: 1.294996  [38400/80000]
# loss: 1.302863  [51200/80000]
# loss: 1.379740  [64000/80000]
# loss: 1.248370  [76800/80000]
# Test Error:
#  Accuracy: 57.3%, Avg loss: 1.326920, torch metrics acc: 57.3%
#
# recall of every test dataset class:  tensor(0.3895, device='cuda:0')
# precision of every test dataset class:  tensor(0.3392, device='cuda:0')
# auc: 0.6953383684158325
# Epoch 15
# -------------------------------
# loss: 1.314628  [    0/80000]
# loss: 1.318934  [12800/80000]
# loss: 1.347684  [25600/80000]
# loss: 1.285927  [38400/80000]
# loss: 1.274748  [51200/80000]
# loss: 1.377968  [64000/80000]
# loss: 1.340301  [76800/80000]
# Test Error:
#  Accuracy: 57.2%, Avg loss: 1.329103, torch metrics acc: 57.2%
#
# recall of every test dataset class:  tensor(0.4028, device='cuda:0')
# precision of every test dataset class:  tensor(0.3440, device='cuda:0')
# auc: 0.678644061088562
# Epoch 16
# -------------------------------
# loss: 1.331864  [    0/80000]
# loss: 1.347113  [12800/80000]
# loss: 1.344847  [25600/80000]
# loss: 1.324061  [38400/80000]
# loss: 1.345576  [51200/80000]
# loss: 1.307037  [64000/80000]
# loss: 1.317188  [76800/80000]
# Test Error:
#  Accuracy: 57.7%, Avg loss: 1.324333, torch metrics acc: 57.7%
#
# recall of every test dataset class:  tensor(0.3982, device='cuda:0')
# precision of every test dataset class:  tensor(0.3412, device='cuda:0')
# auc: 0.6888120770454407
# Epoch 17
# -------------------------------
# loss: 1.330340  [    0/80000]
# loss: 1.268814  [12800/80000]
# loss: 1.271803  [25600/80000]
# loss: 1.228570  [38400/80000]
# loss: 1.326231  [51200/80000]
# loss: 1.284340  [64000/80000]
# loss: 1.376453  [76800/80000]
# Test Error:
#  Accuracy: 57.6%, Avg loss: 1.322560, torch metrics acc: 57.7%
#
# recall of every test dataset class:  tensor(0.3985, device='cuda:0')
# precision of every test dataset class:  tensor(0.3466, device='cuda:0')
# auc: 0.6854890584945679
# Epoch 18
# -------------------------------
# loss: 1.340467  [    0/80000]
# loss: 1.340564  [12800/80000]
# loss: 1.330378  [25600/80000]
# loss: 1.290462  [38400/80000]
# loss: 1.308338  [51200/80000]
# loss: 1.401385  [64000/80000]
# loss: 1.322569  [76800/80000]
# Test Error:
#  Accuracy: 57.6%, Avg loss: 1.323672, torch metrics acc: 57.6%
#
# recall of every test dataset class:  tensor(0.3992, device='cuda:0')
# precision of every test dataset class:  tensor(0.3474, device='cuda:0')
# auc: 0.6815560460090637
# Epoch 19
# -------------------------------
# loss: 1.323700  [    0/80000]
# loss: 1.306702  [12800/80000]
# loss: 1.358232  [25600/80000]
# loss: 1.364912  [38400/80000]
# loss: 1.247664  [51200/80000]
# loss: 1.342455  [64000/80000]
# loss: 1.258489  [76800/80000]
# Test Error:
#  Accuracy: 57.9%, Avg loss: 1.323598, torch metrics acc: 57.9%
#
# recall of every test dataset class:  tensor(0.4046, device='cuda:0')
# precision of every test dataset class:  tensor(0.3452, device='cuda:0')
# auc: 0.6819832921028137
# Epoch 20
# -------------------------------
# loss: 1.323839  [    0/80000]
# loss: 1.337380  [12800/80000]
# loss: 1.338114  [25600/80000]
# loss: 1.328140  [38400/80000]
# loss: 1.363000  [51200/80000]
# loss: 1.266789  [64000/80000]
# loss: 1.364826  [76800/80000]
# Test Error:
#  Accuracy: 58.0%, Avg loss: 1.320900, torch metrics acc: 58.0%
#
# recall of every test dataset class:  tensor(0.3983, device='cuda:0')
# precision of every test dataset class:  tensor(0.3415, device='cuda:0')
# auc: 0.6914777159690857
# Epoch 21
# -------------------------------
# loss: 1.290226  [    0/80000]
# loss: 1.356212  [12800/80000]
# loss: 1.325306  [25600/80000]
# loss: 1.393386  [38400/80000]
# loss: 1.334458  [51200/80000]
# loss: 1.311441  [64000/80000]
# loss: 1.306116  [76800/80000]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.317993, torch metrics acc: 58.1%
#
# recall of every test dataset class:  tensor(0.4002, device='cuda:0')
# precision of every test dataset class:  tensor(0.3467, device='cuda:0')
# auc: 0.6865922212600708
# Epoch 22
# -------------------------------
# loss: 1.304570  [    0/80000]
# loss: 1.289830  [12800/80000]
# loss: 1.307792  [25600/80000]
# loss: 1.287437  [38400/80000]
# loss: 1.309008  [51200/80000]
# loss: 1.347371  [64000/80000]
# loss: 1.285147  [76800/80000]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.318397, torch metrics acc: 58.1%
#
# recall of every test dataset class:  tensor(0.4030, device='cuda:0')
# precision of every test dataset class:  tensor(0.3474, device='cuda:0')
# auc: 0.6845738291740417
# Epoch 23
# -------------------------------
# loss: 1.317376  [    0/80000]
# loss: 1.382980  [12800/80000]
# loss: 1.337725  [25600/80000]
# loss: 1.341641  [38400/80000]
# loss: 1.323979  [51200/80000]
# loss: 1.291160  [64000/80000]
# loss: 1.377770  [76800/80000]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.315785, torch metrics acc: 58.1%
#
# recall of every test dataset class:  tensor(0.4040, device='cuda:0')
# precision of every test dataset class:  tensor(0.3447, device='cuda:0')
# auc: 0.6864280700683594
# Epoch 24
# -------------------------------
# loss: 1.281676  [    0/80000]
# loss: 1.321546  [12800/80000]
# loss: 1.321985  [25600/80000]
# loss: 1.354631  [38400/80000]
# loss: 1.272228  [51200/80000]
# loss: 1.248741  [64000/80000]
# loss: 1.290805  [76800/80000]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 1.318131, torch metrics acc: 58.3%
#
# recall of every test dataset class:  tensor(0.4061, device='cuda:0')
# precision of every test dataset class:  tensor(0.3497, device='cuda:0')
# auc: 0.6823821067810059
# Epoch 25
# -------------------------------
# loss: 1.248638  [    0/80000]
# loss: 1.312499  [12800/80000]
# loss: 1.280380  [25600/80000]
# loss: 1.268354  [38400/80000]
# loss: 1.313696  [51200/80000]
# loss: 1.274104  [64000/80000]
# loss: 1.310175  [76800/80000]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.316357, torch metrics acc: 58.1%
#
# recall of every test dataset class:  tensor(0.4029, device='cuda:0')
# precision of every test dataset class:  tensor(0.3426, device='cuda:0')
# auc: 0.6895476579666138
# Epoch 26
# -------------------------------
# loss: 1.338465  [    0/80000]
# loss: 1.294039  [12800/80000]
# loss: 1.358596  [25600/80000]
# loss: 1.299108  [38400/80000]
# loss: 1.321068  [51200/80000]
# loss: 1.360017  [64000/80000]
# loss: 1.315564  [76800/80000]
# Test Error:
#  Accuracy: 58.2%, Avg loss: 1.314970, torch metrics acc: 58.2%
#
# recall of every test dataset class:  tensor(0.4061, device='cuda:0')
# precision of every test dataset class:  tensor(0.3481, device='cuda:0')
# auc: 0.6837815642356873
# Epoch 27
# -------------------------------
# loss: 1.301671  [    0/80000]
# loss: 1.323076  [12800/80000]
# loss: 1.297019  [25600/80000]
# loss: 1.316139  [38400/80000]
# loss: 1.212290  [51200/80000]
# loss: 1.269901  [64000/80000]
# loss: 1.235079  [76800/80000]
# Test Error:
#  Accuracy: 58.2%, Avg loss: 1.317096, torch metrics acc: 58.2%
#
# recall of every test dataset class:  tensor(0.4007, device='cuda:0')
# precision of every test dataset class:  tensor(0.3425, device='cuda:0')
# auc: 0.6941771507263184
# Epoch 28
# -------------------------------
# loss: 1.347098  [    0/80000]
# loss: 1.256060  [12800/80000]
# loss: 1.381912  [25600/80000]
# loss: 1.329623  [38400/80000]
# loss: 1.323286  [51200/80000]
# loss: 1.299756  [64000/80000]
# loss: 1.354071  [76800/80000]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.317152, torch metrics acc: 58.1%
#
# recall of every test dataset class:  tensor(0.3999, device='cuda:0')
# precision of every test dataset class:  tensor(0.3485, device='cuda:0')
# auc: 0.6885083913803101
# Epoch 29
# -------------------------------
# loss: 1.314672  [    0/80000]
# loss: 1.333780  [12800/80000]
# loss: 1.331052  [25600/80000]
# loss: 1.296482  [38400/80000]
# loss: 1.231187  [51200/80000]
# loss: 1.309414  [64000/80000]
# loss: 1.321363  [76800/80000]
# Test Error:
#  Accuracy: 58.0%, Avg loss: 1.316812, torch metrics acc: 58.0%
#
# recall of every test dataset class:  tensor(0.4015, device='cuda:0')
# precision of every test dataset class:  tensor(0.3416, device='cuda:0')
# auc: 0.6915440559387207
# Epoch 30
# -------------------------------
# loss: 1.277561  [    0/80000]
# loss: 1.323396  [12800/80000]
# loss: 1.309529  [25600/80000]
# loss: 1.330762  [38400/80000]
# loss: 1.263082  [51200/80000]
# loss: 1.267726  [64000/80000]
# loss: 1.297614  [76800/80000]
# Test Error:
#  Accuracy: 58.1%, Avg loss: 1.320350, torch metrics acc: 58.1%
#
# recall of every test dataset class:  tensor(0.4051, device='cuda:0')
# precision of every test dataset class:  tensor(0.3533, device='cuda:0')
# auc: 0.6819087266921997
# Epoch 31
# -------------------------------
# loss: 1.314593  [    0/80000]
# loss: 1.305560  [12800/80000]
# loss: 1.361288  [25600/80000]
# loss: 1.323675  [38400/80000]
# loss: 1.280242  [51200/80000]
# loss: 1.331489  [64000/80000]
# loss: 1.272985  [76800/80000]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 1.313462, torch metrics acc: 58.5%
#
# recall of every test dataset class:  tensor(0.4065, device='cuda:0')
# precision of every test dataset class:  tensor(0.3507, device='cuda:0')
# auc: 0.6880578994750977
# Epoch 32
# -------------------------------
# loss: 1.310241  [    0/80000]
# loss: 1.311559  [12800/80000]
# loss: 1.354779  [25600/80000]
# loss: 1.246467  [38400/80000]
# loss: 1.332526  [51200/80000]
# loss: 1.305190  [64000/80000]
# loss: 1.269968  [76800/80000]
# Test Error:
#  Accuracy: 58.8%, Avg loss: 1.313380, torch metrics acc: 58.7%
#
# recall of every test dataset class:  tensor(0.4116, device='cuda:0')
# precision of every test dataset class:  tensor(0.3520, device='cuda:0')
# auc: 0.6877013444900513
# Epoch 33
# -------------------------------
# loss: 1.262102  [    0/80000]
# loss: 1.356247  [12800/80000]
# loss: 1.245455  [25600/80000]
# loss: 1.243798  [38400/80000]
# loss: 1.297640  [51200/80000]
# loss: 1.329763  [64000/80000]
# loss: 1.312468  [76800/80000]
# Test Error:
#  Accuracy: 58.2%, Avg loss: 1.315644, torch metrics acc: 58.2%
#
# recall of every test dataset class:  tensor(0.4025, device='cuda:0')
# precision of every test dataset class:  tensor(0.3513, device='cuda:0')
# auc: 0.6897591352462769
# Epoch 34
# -------------------------------
# loss: 1.308316  [    0/80000]
# loss: 1.306083  [12800/80000]
# loss: 1.282840  [25600/80000]
# loss: 1.264336  [38400/80000]
# loss: 1.317064  [51200/80000]
# loss: 1.309018  [64000/80000]
# loss: 1.374269  [76800/80000]
# Test Error:
#  Accuracy: 58.9%, Avg loss: 1.312423, torch metrics acc: 58.9%
#
# recall of every test dataset class:  tensor(0.4125, device='cuda:0')
# precision of every test dataset class:  tensor(0.3530, device='cuda:0')
# auc: 0.6893362402915955
# Epoch 35
# -------------------------------
# loss: 1.248772  [    0/80000]
# loss: 1.316712  [12800/80000]
# loss: 1.342613  [25600/80000]
# loss: 1.347259  [38400/80000]
# loss: 1.264339  [51200/80000]
# loss: 1.303857  [64000/80000]
# loss: 1.297958  [76800/80000]
# Test Error:
#  Accuracy: 58.6%, Avg loss: 1.311945, torch metrics acc: 58.6%
#
# recall of every test dataset class:  tensor(0.4072, device='cuda:0')
# precision of every test dataset class:  tensor(0.3485, device='cuda:0')
# auc: 0.6960716843605042
# Epoch 36
# -------------------------------
# loss: 1.299450  [    0/80000]
# loss: 1.319865  [12800/80000]
# loss: 1.226464  [25600/80000]
# loss: 1.348561  [38400/80000]
# loss: 1.249211  [51200/80000]
# loss: 1.324316  [64000/80000]
# loss: 1.273404  [76800/80000]
# Test Error:
#  Accuracy: 58.7%, Avg loss: 1.315683, torch metrics acc: 58.7%
#
# recall of every test dataset class:  tensor(0.4120, device='cuda:0')
# precision of every test dataset class:  tensor(0.3553, device='cuda:0')
# auc: 0.6877341270446777
# Epoch 37
# -------------------------------
# loss: 1.301539  [    0/80000]
# loss: 1.311068  [12800/80000]
# loss: 1.318082  [25600/80000]
# loss: 1.337552  [38400/80000]
# loss: 1.289360  [51200/80000]
# loss: 1.308761  [64000/80000]
# loss: 1.367269  [76800/80000]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 1.315412, torch metrics acc: 58.3%
#
# recall of every test dataset class:  tensor(0.3987, device='cuda:0')
# precision of every test dataset class:  tensor(0.3433, device='cuda:0')
# auc: 0.7041140198707581
# Epoch 38
# -------------------------------
# loss: 1.257887  [    0/80000]
# loss: 1.321607  [12800/80000]
# loss: 1.301880  [25600/80000]
# loss: 1.299992  [38400/80000]
# loss: 1.273757  [51200/80000]
# loss: 1.305879  [64000/80000]
# loss: 1.340178  [76800/80000]
# Test Error:
#  Accuracy: 58.2%, Avg loss: 1.317903, torch metrics acc: 58.2%
#
# recall of every test dataset class:  tensor(0.4060, device='cuda:0')
# precision of every test dataset class:  tensor(0.3534, device='cuda:0')
# auc: 0.6905669569969177
# Epoch 39
# -------------------------------
# loss: 1.242541  [    0/80000]
# loss: 1.337672  [12800/80000]
# loss: 1.290279  [25600/80000]
# loss: 1.349956  [38400/80000]
# loss: 1.369995  [51200/80000]
# loss: 1.277892  [64000/80000]
# loss: 1.363927  [76800/80000]
# Test Error:
#  Accuracy: 58.6%, Avg loss: 1.309996, torch metrics acc: 58.6%
#
# recall of every test dataset class:  tensor(0.4048, device='cuda:0')
# precision of every test dataset class:  tensor(0.3469, device='cuda:0')
# auc: 0.7032530307769775
# Epoch 40
# -------------------------------
# loss: 1.318216  [    0/80000]
# loss: 1.258124  [12800/80000]
# loss: 1.335729  [25600/80000]
# loss: 1.338277  [38400/80000]
# loss: 1.347054  [51200/80000]
# loss: 1.280291  [64000/80000]
# loss: 1.308847  [76800/80000]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 1.311765, torch metrics acc: 58.5%
#
# recall of every test dataset class:  tensor(0.4030, device='cuda:0')
# precision of every test dataset class:  tensor(0.3482, device='cuda:0')
# auc: 0.7046610116958618
# Epoch 41
# -------------------------------
# loss: 1.359249  [    0/80000]
# loss: 1.297655  [12800/80000]
# loss: 1.321988  [25600/80000]
# loss: 1.253947  [38400/80000]
# loss: 1.355427  [51200/80000]
# loss: 1.326610  [64000/80000]
# loss: 1.283640  [76800/80000]
# Test Error:
#  Accuracy: 58.7%, Avg loss: 1.307820, torch metrics acc: 58.7%
#
# recall of every test dataset class:  tensor(0.4038, device='cuda:0')
# precision of every test dataset class:  tensor(0.3481, device='cuda:0')
# auc: 0.710016667842865
# Epoch 42
# -------------------------------
# loss: 1.273741  [    0/80000]
# loss: 1.280531  [12800/80000]
# loss: 1.332035  [25600/80000]
# loss: 1.260070  [38400/80000]
# loss: 1.267614  [51200/80000]
# loss: 1.337703  [64000/80000]
# loss: 1.315944  [76800/80000]
# Test Error:
#  Accuracy: 58.4%, Avg loss: 1.313709, torch metrics acc: 58.4%
#
# recall of every test dataset class:  tensor(0.4016, device='cuda:0')
# precision of every test dataset class:  tensor(0.3507, device='cuda:0')
# auc: 0.7149970531463623
# Epoch 43
# -------------------------------
# loss: 1.220594  [    0/80000]
# loss: 1.370552  [12800/80000]
# loss: 1.331924  [25600/80000]
# loss: 1.345591  [38400/80000]
# loss: 1.306211  [51200/80000]
# loss: 1.312812  [64000/80000]
# loss: 1.274420  [76800/80000]
# Test Error:
#  Accuracy: 59.2%, Avg loss: 1.307002, torch metrics acc: 59.2%
#
# recall of every test dataset class:  tensor(0.4310, device='cuda:0')
# precision of every test dataset class:  tensor(0.4402, device='cuda:0')
# auc: 0.7316421866416931
# Epoch 44
# -------------------------------
# loss: 1.246915  [    0/80000]
# loss: 1.296519  [12800/80000]
# loss: 1.294534  [25600/80000]
# loss: 1.353352  [38400/80000]
# loss: 1.289723  [51200/80000]
# loss: 1.332551  [64000/80000]
# loss: 1.350191  [76800/80000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 1.303077, torch metrics acc: 59.7%
#
# recall of every test dataset class:  tensor(0.4481, device='cuda:0')
# precision of every test dataset class:  tensor(0.4594, device='cuda:0')
# auc: 0.741066575050354
# Epoch 45
# -------------------------------
# loss: 1.287175  [    0/80000]
# loss: 1.289584  [12800/80000]
# loss: 1.336807  [25600/80000]
# loss: 1.286676  [38400/80000]
# loss: 1.260092  [51200/80000]
# loss: 1.363845  [64000/80000]
# loss: 1.331121  [76800/80000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 1.302567, torch metrics acc: 59.7%
#
# recall of every test dataset class:  tensor(0.4496, device='cuda:0')
# precision of every test dataset class:  tensor(0.4549, device='cuda:0')
# auc: 0.7426866888999939
# Epoch 46
# -------------------------------
# loss: 1.227161  [    0/80000]
# loss: 1.292000  [12800/80000]
# loss: 1.256165  [25600/80000]
# loss: 1.293398  [38400/80000]
# loss: 1.261613  [51200/80000]
# loss: 1.296131  [64000/80000]
# loss: 1.264919  [76800/80000]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 1.301988, torch metrics acc: 60.0%
#
# recall of every test dataset class:  tensor(0.4556, device='cuda:0')
# precision of every test dataset class:  tensor(0.4628, device='cuda:0')
# auc: 0.743627667427063
# Epoch 47
# -------------------------------
# loss: 1.283220  [    0/80000]
# loss: 1.288182  [12800/80000]
# loss: 1.307098  [25600/80000]
# loss: 1.297326  [38400/80000]
# loss: 1.347142  [51200/80000]
# loss: 1.280760  [64000/80000]
# loss: 1.284814  [76800/80000]
# Test Error:
#  Accuracy: 59.6%, Avg loss: 1.304497, torch metrics acc: 59.5%
#
# recall of every test dataset class:  tensor(0.4487, device='cuda:0')
# precision of every test dataset class:  tensor(0.4640, device='cuda:0')
# auc: 0.7484053373336792
# Epoch 48
# -------------------------------
# loss: 1.317268  [    0/80000]
# loss: 1.396212  [12800/80000]
# loss: 1.245431  [25600/80000]
# loss: 1.306137  [38400/80000]
# loss: 1.285150  [51200/80000]
# loss: 1.357373  [64000/80000]
# loss: 1.364110  [76800/80000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 1.302380, torch metrics acc: 59.7%
#
# recall of every test dataset class:  tensor(0.4557, device='cuda:0')
# precision of every test dataset class:  tensor(0.4514, device='cuda:0')
# auc: 0.7488598227500916
# Epoch 49
# -------------------------------
# loss: 1.262516  [    0/80000]
# loss: 1.360932  [12800/80000]
# loss: 1.307245  [25600/80000]
# loss: 1.313038  [38400/80000]
# loss: 1.275066  [51200/80000]
# loss: 1.357262  [64000/80000]
# loss: 1.294399  [76800/80000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 1.301487, torch metrics acc: 59.7%
#
# recall of every test dataset class:  tensor(0.4539, device='cuda:0')
# precision of every test dataset class:  tensor(0.4556, device='cuda:0')
# auc: 0.7494492530822754
# Epoch 50
# -------------------------------
# loss: 1.278703  [    0/80000]
# loss: 1.329912  [12800/80000]
# loss: 1.266386  [25600/80000]
# loss: 1.235692  [38400/80000]
# loss: 1.308604  [51200/80000]
# loss: 1.287074  [64000/80000]
# loss: 1.320016  [76800/80000]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 1.300051, torch metrics acc: 59.8%
#
# recall of every test dataset class:  tensor(0.4618, device='cuda:0')
# precision of every test dataset class:  tensor(0.4556, device='cuda:0')
# auc: 0.7506563663482666
# Epoch 51
# -------------------------------
# loss: 1.341450  [    0/80000]
# loss: 1.370797  [12800/80000]
# loss: 1.269819  [25600/80000]
# loss: 1.348085  [38400/80000]
# loss: 1.289543  [51200/80000]
# loss: 1.267857  [64000/80000]
# loss: 1.288239  [76800/80000]
# Test Error:
#  Accuracy: 59.5%, Avg loss: 1.303042, torch metrics acc: 59.5%
#
# recall of every test dataset class:  tensor(0.4561, device='cuda:0')
# precision of every test dataset class:  tensor(0.4474, device='cuda:0')
# auc: 0.753147542476654
# Epoch 52
# -------------------------------
# loss: 1.336307  [    0/80000]
# loss: 1.259875  [12800/80000]
# loss: 1.330417  [25600/80000]
# loss: 1.359124  [38400/80000]
# loss: 1.346739  [51200/80000]
# loss: 1.253404  [64000/80000]
# loss: 1.329580  [76800/80000]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 1.299771, torch metrics acc: 60.0%
#
# recall of every test dataset class:  tensor(0.4595, device='cuda:0')
# precision of every test dataset class:  tensor(0.4667, device='cuda:0')
# auc: 0.7489284873008728
# Epoch 53
# -------------------------------
# loss: 1.259376  [    0/80000]
# loss: 1.284443  [12800/80000]
# loss: 1.306992  [25600/80000]
# loss: 1.313509  [38400/80000]
# loss: 1.347700  [51200/80000]
# loss: 1.265676  [64000/80000]
# loss: 1.332048  [76800/80000]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 1.301748, torch metrics acc: 59.8%
#
# recall of every test dataset class:  tensor(0.4578, device='cuda:0')
# precision of every test dataset class:  tensor(0.4620, device='cuda:0')
# auc: 0.7511929869651794
# Epoch 54
# -------------------------------
# loss: 1.294005  [    0/80000]
# loss: 1.305289  [12800/80000]
# loss: 1.356055  [25600/80000]
# loss: 1.252494  [38400/80000]
# loss: 1.237203  [51200/80000]
# loss: 1.315063  [64000/80000]
# loss: 1.285506  [76800/80000]
# Test Error:
#  Accuracy: 59.5%, Avg loss: 1.304447, torch metrics acc: 59.5%
#
# recall of every test dataset class:  tensor(0.4630, device='cuda:0')
# precision of every test dataset class:  tensor(0.4555, device='cuda:0')
# auc: 0.7510637640953064
# Epoch 55
# -------------------------------
# loss: 1.366161  [    0/80000]
# loss: 1.332315  [12800/80000]
# loss: 1.249353  [25600/80000]
# loss: 1.243006  [38400/80000]
# loss: 1.289050  [51200/80000]
# loss: 1.301595  [64000/80000]
# loss: 1.332933  [76800/80000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 1.299946, torch metrics acc: 59.7%
#
# recall of every test dataset class:  tensor(0.4545, device='cuda:0')
# precision of every test dataset class:  tensor(0.4572, device='cuda:0')
# auc: 0.7543131113052368
# Epoch 56
# -------------------------------
# loss: 1.267526  [    0/80000]
# loss: 1.337273  [12800/80000]
# loss: 1.386607  [25600/80000]
# loss: 1.305502  [38400/80000]
# loss: 1.265607  [51200/80000]
# loss: 1.240900  [64000/80000]
# loss: 1.252538  [76800/80000]
# Test Error:
#  Accuracy: 60.2%, Avg loss: 1.299325, torch metrics acc: 60.2%
#
# recall of every test dataset class:  tensor(0.4611, device='cuda:0')
# precision of every test dataset class:  tensor(0.4675, device='cuda:0')
# auc: 0.7513570189476013
# Epoch 57
# -------------------------------
# loss: 1.369364  [    0/80000]
# loss: 1.240253  [12800/80000]
# loss: 1.346931  [25600/80000]
# loss: 1.282334  [38400/80000]
# loss: 1.254716  [51200/80000]
# loss: 1.256251  [64000/80000]
# loss: 1.288469  [76800/80000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 1.302701, torch metrics acc: 59.7%
#
# recall of every test dataset class:  tensor(0.4664, device='cuda:0')
# precision of every test dataset class:  tensor(0.4601, device='cuda:0')
# auc: 0.7519373297691345
# Epoch 58
# -------------------------------
# loss: 1.334671  [    0/80000]
# loss: 1.290068  [12800/80000]
# loss: 1.265549  [25600/80000]
# loss: 1.265577  [38400/80000]
# loss: 1.278823  [51200/80000]
# loss: 1.298615  [64000/80000]
# loss: 1.379617  [76800/80000]
# Test Error:
#  Accuracy: 60.2%, Avg loss: 1.296580, torch metrics acc: 60.2%
#
# recall of every test dataset class:  tensor(0.4693, device='cuda:0')
# precision of every test dataset class:  tensor(0.4558, device='cuda:0')
# auc: 0.7533551454544067
# Epoch 59
# -------------------------------
# loss: 1.241285  [    0/80000]
# loss: 1.301056  [12800/80000]
# loss: 1.273640  [25600/80000]
# loss: 1.287077  [38400/80000]
# loss: 1.333415  [51200/80000]
# loss: 1.335606  [64000/80000]
# loss: 1.280112  [76800/80000]
# Test Error:
#  Accuracy: 60.2%, Avg loss: 1.299608, torch metrics acc: 60.1%
#
# recall of every test dataset class:  tensor(0.4568, device='cuda:0')
# precision of every test dataset class:  tensor(0.4728, device='cuda:0')
# auc: 0.7514805197715759
# Epoch 60
# -------------------------------
# loss: 1.330896  [    0/80000]
# loss: 1.347356  [12800/80000]
# loss: 1.299495  [25600/80000]
# loss: 1.219837  [38400/80000]
# loss: 1.322949  [51200/80000]
# loss: 1.308102  [64000/80000]
# loss: 1.365625  [76800/80000]
# Test Error:
#  Accuracy: 60.3%, Avg loss: 1.297288, torch metrics acc: 60.3%
#
# recall of every test dataset class:  tensor(0.4650, device='cuda:0')
# precision of every test dataset class:  tensor(0.4670, device='cuda:0')
# auc: 0.7535941004753113
# Epoch 61
# -------------------------------
# loss: 1.220663  [    0/80000]
# loss: 1.323280  [12800/80000]
# loss: 1.299885  [25600/80000]
# loss: 1.247713  [38400/80000]
# loss: 1.238877  [51200/80000]
# loss: 1.298646  [64000/80000]
# loss: 1.307905  [76800/80000]
# Test Error:
#  Accuracy: 60.2%, Avg loss: 1.299068, torch metrics acc: 60.2%
#
# recall of every test dataset class:  tensor(0.4659, device='cuda:0')
# precision of every test dataset class:  tensor(0.4678, device='cuda:0')
# auc: 0.7512025237083435
# Epoch 62
# -------------------------------
# loss: 1.286737  [    0/80000]
# loss: 1.330386  [12800/80000]
# loss: 1.314503  [25600/80000]
# loss: 1.224447  [38400/80000]
# loss: 1.285212  [51200/80000]
# loss: 1.403491  [64000/80000]
# loss: 1.288988  [76800/80000]
# Test Error:
#  Accuracy: 60.1%, Avg loss: 1.298416, torch metrics acc: 60.0%
#
# recall of every test dataset class:  tensor(0.4650, device='cuda:0')
# precision of every test dataset class:  tensor(0.4580, device='cuda:0')
# auc: 0.7554230093955994
# Epoch 63
# -------------------------------
# loss: 1.258070  [    0/80000]
# loss: 1.278520  [12800/80000]
# loss: 1.282357  [25600/80000]
# loss: 1.258136  [38400/80000]
# loss: 1.227848  [51200/80000]
# loss: 1.317273  [64000/80000]
# loss: 1.319696  [76800/80000]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 1.300639, torch metrics acc: 60.0%
#
# recall of every test dataset class:  tensor(0.4582, device='cuda:0')
# precision of every test dataset class:  tensor(0.4637, device='cuda:0')
# auc: 0.7569733262062073
# Epoch 64
# -------------------------------
# loss: 1.304031  [    0/80000]
# loss: 1.330548  [12800/80000]
# loss: 1.289528  [25600/80000]
# loss: 1.274218  [38400/80000]
# loss: 1.297096  [51200/80000]
# loss: 1.298916  [64000/80000]
# loss: 1.271749  [76800/80000]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 1.299112, torch metrics acc: 60.0%
#
# recall of every test dataset class:  tensor(0.4672, device='cuda:0')
# precision of every test dataset class:  tensor(0.4556, device='cuda:0')
# auc: 0.7519928812980652
# Epoch 65
# -------------------------------
# loss: 1.299834  [    0/80000]
# loss: 1.285188  [12800/80000]
# loss: 1.294611  [25600/80000]
# loss: 1.332981  [38400/80000]
# loss: 1.296974  [51200/80000]
# loss: 1.281948  [64000/80000]
# loss: 1.244881  [76800/80000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 1.300977, torch metrics acc: 59.7%
#
# recall of every test dataset class:  tensor(0.4593, device='cuda:0')
# precision of every test dataset class:  tensor(0.4653, device='cuda:0')
# auc: 0.7562386989593506
# Epoch 66
# -------------------------------
# loss: 1.227893  [    0/80000]
# loss: 1.363295  [12800/80000]
# loss: 1.292042  [25600/80000]
# loss: 1.317679  [38400/80000]
# loss: 1.313465  [51200/80000]
# loss: 1.265352  [64000/80000]
# loss: 1.292459  [76800/80000]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 1.298319, torch metrics acc: 59.8%
#
# recall of every test dataset class:  tensor(0.4567, device='cuda:0')
# precision of every test dataset class:  tensor(0.4562, device='cuda:0')
# auc: 0.7577378153800964
# Epoch 67
# -------------------------------
# loss: 1.283050  [    0/80000]
# loss: 1.273797  [12800/80000]
# loss: 1.334823  [25600/80000]
# loss: 1.286541  [38400/80000]
# loss: 1.314876  [51200/80000]
# loss: 1.271514  [64000/80000]
# loss: 1.254574  [76800/80000]
# Test Error:
#  Accuracy: 59.9%, Avg loss: 1.298140, torch metrics acc: 59.9%
#
# recall of every test dataset class:  tensor(0.4619, device='cuda:0')
# precision of every test dataset class:  tensor(0.4562, device='cuda:0')
# auc: 0.7584372758865356
# Epoch 68
# -------------------------------
# loss: 1.330429  [    0/80000]
# loss: 1.304356  [12800/80000]
# loss: 1.311462  [25600/80000]
# loss: 1.264719  [38400/80000]
# loss: 1.284891  [51200/80000]
# loss: 1.259923  [64000/80000]
# loss: 1.306325  [76800/80000]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 1.301479, torch metrics acc: 60.0%
#
# recall of every test dataset class:  tensor(0.4665, device='cuda:0')
# precision of every test dataset class:  tensor(0.4596, device='cuda:0')
# auc: 0.7564125657081604
# Epoch 69
# -------------------------------
# loss: 1.317836  [    0/80000]
# loss: 1.266851  [12800/80000]
# loss: 1.269822  [25600/80000]
# loss: 1.278733  [38400/80000]
# loss: 1.270962  [51200/80000]
# loss: 1.348127  [64000/80000]
# loss: 1.390781  [76800/80000]
# Test Error:
#  Accuracy: 59.8%, Avg loss: 1.297838, torch metrics acc: 59.8%
#
# recall of every test dataset class:  tensor(0.4661, device='cuda:0')
# precision of every test dataset class:  tensor(0.4561, device='cuda:0')
# auc: 0.7584680914878845
# early stop!
# Best Accuracy: 0.603000
#
# Done!
# Test Error:
#  Accuracy: 59.3%, Avg loss: 1.306475, torch metrics acc: 59.3%
#
# recall of every test dataset class:  tensor(0.4592, device='cuda:0')
# precision of every test dataset class:  tensor(0.4578, device='cuda:0')
# auc: 0.7548519372940063
# 0.5932

# %%
model = NeuralNetwork_gender().to(device)
print(model)

warmup_epoch = 5
iter_per_epoch = len(train_loader_age)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=0.5, total_iters=20)
# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

cost = []
val = []

best_correct = 0
bestValLoss = float('inf')
es = 0
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    epoch_loss = train_loop(train_loader_gender, model, loss_fn, optimizer, t)
    cost.append(epoch_loss)
    epoch_loss, correct = test_loop(valid_loader_gender, model, loss_fn, 2)

    scheduler.step()

    val.append(epoch_loss)
    if correct > best_correct:
        best_correct = correct
    #更新状态
    if epoch_loss < bestValLoss:
        bestValLoss = epoch_loss
        es = 0
    else:
    #early stop
        es += 1
        if es > 10:
            print("early stop!")
            break
print(f"Best Accuracy: {(best_correct):>8f}\n")
print("Done!")

plt.plot(np.squeeze(cost),'-r', np.squeeze(val),'-b')
plt.ylabel('gender loss')
plt.xlabel('Epoch')
plt.show()

epoch_loss, correct = test_loop(test_loader_gender, model, loss_fn, 2)
print(correct)
import time
print(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
# Out:
# NeuralNetwork_gender(
#   (dnn): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=32, out_features=2, bias=True)
#     (5): Softmax(dim=None)
#   )
# )
# Epoch 1
# -------------------------------
# loss: 0.757924  [    0/80000]
# loss: 0.657759  [12800/80000]
# loss: 0.600898  [25600/80000]
# loss: 0.508060  [38400/80000]
# loss: 0.483025  [51200/80000]
# loss: 0.433721  [64000/80000]
# loss: 0.427088  [76800/80000]
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.438514, torch metrics acc: 91.3%
#
# recall of every test dataset class:  tensor(0.9127, device='cuda:0')
# precision of every test dataset class:  tensor(0.9137, device='cuda:0')
# auc: 0.9698578119277954
# Epoch 2
# -------------------------------
# loss: 0.451630  [    0/80000]
# loss: 0.431712  [12800/80000]
# loss: 0.444299  [25600/80000]
# loss: 0.393938  [38400/80000]
# loss: 0.409026  [51200/80000]
# loss: 0.408499  [64000/80000]
# loss: 0.409022  [76800/80000]
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.394225, torch metrics acc: 92.9%
#
# recall of every test dataset class:  tensor(0.9282, device='cuda:0')
# precision of every test dataset class:  tensor(0.9302, device='cuda:0')
# auc: 0.980976939201355
# Epoch 3
# -------------------------------
# loss: 0.385862  [    0/80000]
# loss: 0.382711  [12800/80000]
# loss: 0.352861  [25600/80000]
# loss: 0.383073  [38400/80000]
# loss: 0.374000  [51200/80000]
# loss: 0.410470  [64000/80000]
# loss: 0.369379  [76800/80000]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.384394, torch metrics acc: 93.2%
#
# recall of every test dataset class:  tensor(0.9313, device='cuda:0')
# precision of every test dataset class:  tensor(0.9342, device='cuda:0')
# auc: 0.9832017421722412
# Epoch 4
# -------------------------------
# loss: 0.382589  [    0/80000]
# loss: 0.388227  [12800/80000]
# loss: 0.392494  [25600/80000]
# loss: 0.377255  [38400/80000]
# loss: 0.365295  [51200/80000]
# loss: 0.360905  [64000/80000]
# loss: 0.391170  [76800/80000]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.377633, torch metrics acc: 94.0%
#
# recall of every test dataset class:  tensor(0.9404, device='cuda:0')
# precision of every test dataset class:  tensor(0.9402, device='cuda:0')
# auc: 0.984086275100708
# Epoch 5
# -------------------------------
# loss: 0.370067  [    0/80000]
# loss: 0.388187  [12800/80000]
# loss: 0.380595  [25600/80000]
# loss: 0.379563  [38400/80000]
# loss: 0.368682  [51200/80000]
# loss: 0.367168  [64000/80000]
# loss: 0.377030  [76800/80000]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.374094, torch metrics acc: 94.2%
#
# recall of every test dataset class:  tensor(0.9415, device='cuda:0')
# precision of every test dataset class:  tensor(0.9415, device='cuda:0')
# auc: 0.9846096634864807
# Epoch 6
# -------------------------------
# loss: 0.352370  [    0/80000]
# loss: 0.395618  [12800/80000]
# loss: 0.399379  [25600/80000]
# loss: 0.403945  [38400/80000]
# loss: 0.370802  [51200/80000]
# loss: 0.343877  [64000/80000]
# loss: 0.410114  [76800/80000]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.371824, torch metrics acc: 94.3%
#
# recall of every test dataset class:  tensor(0.9427, device='cuda:0')
# precision of every test dataset class:  tensor(0.9424, device='cuda:0')
# auc: 0.9850069880485535
# Epoch 7
# -------------------------------
# loss: 0.349061  [    0/80000]
# loss: 0.337444  [12800/80000]
# loss: 0.345450  [25600/80000]
# loss: 0.372141  [38400/80000]
# loss: 0.361714  [51200/80000]
# loss: 0.378010  [64000/80000]
# loss: 0.364440  [76800/80000]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.370523, torch metrics acc: 94.4%
#
# recall of every test dataset class:  tensor(0.9437, device='cuda:0')
# precision of every test dataset class:  tensor(0.9441, device='cuda:0')
# auc: 0.985299825668335
# Epoch 8
# -------------------------------
# loss: 0.381903  [    0/80000]
# loss: 0.389955  [12800/80000]
# loss: 0.378417  [25600/80000]
# loss: 0.409343  [38400/80000]
# loss: 0.361576  [51200/80000]
# loss: 0.387022  [64000/80000]
# loss: 0.385737  [76800/80000]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.368453, torch metrics acc: 94.5%
#
# recall of every test dataset class:  tensor(0.9452, device='cuda:0')
# precision of every test dataset class:  tensor(0.9452, device='cuda:0')
# auc: 0.9854468107223511
# Epoch 9
# -------------------------------
# loss: 0.355354  [    0/80000]
# loss: 0.372078  [12800/80000]
# loss: 0.378882  [25600/80000]
# loss: 0.377472  [38400/80000]
# loss: 0.347090  [51200/80000]
# loss: 0.376693  [64000/80000]
# loss: 0.381885  [76800/80000]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.368260, torch metrics acc: 94.3%
#
# recall of every test dataset class:  tensor(0.9429, device='cuda:0')
# precision of every test dataset class:  tensor(0.9438, device='cuda:0')
# auc: 0.985677182674408
# Epoch 10
# -------------------------------
# loss: 0.374940  [    0/80000]
# loss: 0.370153  [12800/80000]
# loss: 0.354337  [25600/80000]
# loss: 0.362640  [38400/80000]
# loss: 0.368091  [51200/80000]
# loss: 0.366977  [64000/80000]
# loss: 0.376435  [76800/80000]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.367267, torch metrics acc: 94.4%
#
# recall of every test dataset class:  tensor(0.9436, device='cuda:0')
# precision of every test dataset class:  tensor(0.9445, device='cuda:0')
# auc: 0.9858580827713013
# Epoch 11
# -------------------------------
# loss: 0.374240  [    0/80000]
# loss: 0.357879  [12800/80000]
# loss: 0.355476  [25600/80000]
# loss: 0.396211  [38400/80000]
# loss: 0.367752  [51200/80000]
# loss: 0.347052  [64000/80000]
# loss: 0.356041  [76800/80000]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.369500, torch metrics acc: 94.2%
#
# recall of every test dataset class:  tensor(0.9408, device='cuda:0')
# precision of every test dataset class:  tensor(0.9430, device='cuda:0')
# auc: 0.9858827590942383
# Epoch 12
# -------------------------------
# loss: 0.367097  [    0/80000]
# loss: 0.355213  [12800/80000]
# loss: 0.385155  [25600/80000]
# loss: 0.384677  [38400/80000]
# loss: 0.383779  [51200/80000]
# loss: 0.405325  [64000/80000]
# loss: 0.389321  [76800/80000]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.368727, torch metrics acc: 94.2%
#
# recall of every test dataset class:  tensor(0.9411, device='cuda:0')
# precision of every test dataset class:  tensor(0.9428, device='cuda:0')
# auc: 0.9861024618148804
# Epoch 13
# -------------------------------
# loss: 0.359045  [    0/80000]
# loss: 0.330311  [12800/80000]
# loss: 0.366099  [25600/80000]
# loss: 0.358296  [38400/80000]
# loss: 0.343161  [51200/80000]
# loss: 0.351350  [64000/80000]
# loss: 0.380594  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.366074, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9463, device='cuda:0')
# precision of every test dataset class:  tensor(0.9462, device='cuda:0')
# auc: 0.9860880374908447
# Epoch 14
# -------------------------------
# loss: 0.351847  [    0/80000]
# loss: 0.356308  [12800/80000]
# loss: 0.360075  [25600/80000]
# loss: 0.355612  [38400/80000]
# loss: 0.347337  [51200/80000]
# loss: 0.374678  [64000/80000]
# loss: 0.349379  [76800/80000]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.366586, torch metrics acc: 94.4%
#
# recall of every test dataset class:  tensor(0.9436, device='cuda:0')
# precision of every test dataset class:  tensor(0.9448, device='cuda:0')
# auc: 0.9862488508224487
# Epoch 15
# -------------------------------
# loss: 0.352863  [    0/80000]
# loss: 0.357430  [12800/80000]
# loss: 0.371362  [25600/80000]
# loss: 0.389690  [38400/80000]
# loss: 0.342040  [51200/80000]
# loss: 0.375631  [64000/80000]
# loss: 0.350170  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.365676, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9461, device='cuda:0')
# precision of every test dataset class:  tensor(0.9457, device='cuda:0')
# auc: 0.9863244295120239
# Epoch 16
# -------------------------------
# loss: 0.360974  [    0/80000]
# loss: 0.344717  [12800/80000]
# loss: 0.361091  [25600/80000]
# loss: 0.389690  [38400/80000]
# loss: 0.345820  [51200/80000]
# loss: 0.370860  [64000/80000]
# loss: 0.377187  [76800/80000]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.366453, torch metrics acc: 94.4%
#
# recall of every test dataset class:  tensor(0.9435, device='cuda:0')
# precision of every test dataset class:  tensor(0.9447, device='cuda:0')
# auc: 0.9863331317901611
# Epoch 17
# -------------------------------
# loss: 0.352068  [    0/80000]
# loss: 0.366456  [12800/80000]
# loss: 0.399150  [25600/80000]
# loss: 0.351509  [38400/80000]
# loss: 0.361781  [51200/80000]
# loss: 0.367118  [64000/80000]
# loss: 0.355033  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.366700, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9453, device='cuda:0')
# precision of every test dataset class:  tensor(0.9462, device='cuda:0')
# auc: 0.9863376021385193
# Epoch 18
# -------------------------------
# loss: 0.353503  [    0/80000]
# loss: 0.381081  [12800/80000]
# loss: 0.392694  [25600/80000]
# loss: 0.362081  [38400/80000]
# loss: 0.346763  [51200/80000]
# loss: 0.386769  [64000/80000]
# loss: 0.365373  [76800/80000]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.366338, torch metrics acc: 94.3%
#
# recall of every test dataset class:  tensor(0.9421, device='cuda:0')
# precision of every test dataset class:  tensor(0.9437, device='cuda:0')
# auc: 0.9863525032997131
# Epoch 19
# -------------------------------
# loss: 0.357052  [    0/80000]
# loss: 0.365753  [12800/80000]
# loss: 0.376962  [25600/80000]
# loss: 0.357698  [38400/80000]
# loss: 0.358974  [51200/80000]
# loss: 0.360799  [64000/80000]
# loss: 0.366808  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.365210, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9464, device='cuda:0')
# precision of every test dataset class:  tensor(0.9463, device='cuda:0')
# auc: 0.9865328073501587
# Epoch 20
# -------------------------------
# loss: 0.364831  [    0/80000]
# loss: 0.373851  [12800/80000]
# loss: 0.372022  [25600/80000]
# loss: 0.372281  [38400/80000]
# loss: 0.356265  [51200/80000]
# loss: 0.382993  [64000/80000]
# loss: 0.346648  [76800/80000]
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.374201, torch metrics acc: 93.8%
#
# recall of every test dataset class:  tensor(0.9361, device='cuda:0')
# precision of every test dataset class:  tensor(0.9407, device='cuda:0')
# auc: 0.9863759279251099
# Epoch 21
# -------------------------------
# loss: 0.409977  [    0/80000]
# loss: 0.370356  [12800/80000]
# loss: 0.359892  [25600/80000]
# loss: 0.367548  [38400/80000]
# loss: 0.344061  [51200/80000]
# loss: 0.332884  [64000/80000]
# loss: 0.358675  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.364430, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9464, device='cuda:0')
# precision of every test dataset class:  tensor(0.9467, device='cuda:0')
# auc: 0.9865378141403198
# Epoch 22
# -------------------------------
# loss: 0.361339  [    0/80000]
# loss: 0.393480  [12800/80000]
# loss: 0.353500  [25600/80000]
# loss: 0.365309  [38400/80000]
# loss: 0.369018  [51200/80000]
# loss: 0.383431  [64000/80000]
# loss: 0.387900  [76800/80000]
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.368014, torch metrics acc: 94.2%
#
# recall of every test dataset class:  tensor(0.9410, device='cuda:0')
# precision of every test dataset class:  tensor(0.9438, device='cuda:0')
# auc: 0.9865009784698486
# Epoch 23
# -------------------------------
# loss: 0.360856  [    0/80000]
# loss: 0.381998  [12800/80000]
# loss: 0.401768  [25600/80000]
# loss: 0.364629  [38400/80000]
# loss: 0.336949  [51200/80000]
# loss: 0.365648  [64000/80000]
# loss: 0.369418  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.365449, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9468, device='cuda:0')
# precision of every test dataset class:  tensor(0.9467, device='cuda:0')
# auc: 0.9866548776626587
# Epoch 24
# -------------------------------
# loss: 0.347120  [    0/80000]
# loss: 0.333351  [12800/80000]
# loss: 0.348206  [25600/80000]
# loss: 0.358042  [38400/80000]
# loss: 0.356596  [51200/80000]
# loss: 0.349986  [64000/80000]
# loss: 0.347826  [76800/80000]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.366274, torch metrics acc: 94.5%
#
# recall of every test dataset class:  tensor(0.9440, device='cuda:0')
# precision of every test dataset class:  tensor(0.9456, device='cuda:0')
# auc: 0.9865414500236511
# Epoch 25
# -------------------------------
# loss: 0.406232  [    0/80000]
# loss: 0.331395  [12800/80000]
# loss: 0.357590  [25600/80000]
# loss: 0.356939  [38400/80000]
# loss: 0.339159  [51200/80000]
# loss: 0.357962  [64000/80000]
# loss: 0.384742  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.364235, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9461, device='cuda:0')
# precision of every test dataset class:  tensor(0.9466, device='cuda:0')
# auc: 0.9866663217544556
# Epoch 26
# -------------------------------
# loss: 0.356241  [    0/80000]
# loss: 0.376666  [12800/80000]
# loss: 0.365563  [25600/80000]
# loss: 0.388702  [38400/80000]
# loss: 0.364088  [51200/80000]
# loss: 0.357842  [64000/80000]
# loss: 0.357974  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363712, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9469, device='cuda:0')
# precision of every test dataset class:  tensor(0.9468, device='cuda:0')
# auc: 0.9867451190948486
# Epoch 27
# -------------------------------
# loss: 0.365214  [    0/80000]
# loss: 0.360461  [12800/80000]
# loss: 0.354764  [25600/80000]
# loss: 0.359588  [38400/80000]
# loss: 0.349941  [51200/80000]
# loss: 0.365945  [64000/80000]
# loss: 0.389541  [76800/80000]
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.369137, torch metrics acc: 94.1%
#
# recall of every test dataset class:  tensor(0.9402, device='cuda:0')
# precision of every test dataset class:  tensor(0.9435, device='cuda:0')
# auc: 0.9867011308670044
# Epoch 28
# -------------------------------
# loss: 0.360335  [    0/80000]
# loss: 0.348334  [12800/80000]
# loss: 0.354127  [25600/80000]
# loss: 0.358994  [38400/80000]
# loss: 0.344479  [51200/80000]
# loss: 0.355691  [64000/80000]
# loss: 0.401502  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363655, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9475, device='cuda:0')
# precision of every test dataset class:  tensor(0.9471, device='cuda:0')
# auc: 0.9868258237838745
# Epoch 29
# -------------------------------
# loss: 0.383250  [    0/80000]
# loss: 0.358108  [12800/80000]
# loss: 0.398379  [25600/80000]
# loss: 0.396176  [38400/80000]
# loss: 0.359777  [51200/80000]
# loss: 0.400804  [64000/80000]
# loss: 0.348014  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.365711, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9466, device='cuda:0')
# precision of every test dataset class:  tensor(0.9460, device='cuda:0')
# auc: 0.9867146015167236
# Epoch 30
# -------------------------------
# loss: 0.396881  [    0/80000]
# loss: 0.397774  [12800/80000]
# loss: 0.392314  [25600/80000]
# loss: 0.353797  [38400/80000]
# loss: 0.371049  [51200/80000]
# loss: 0.372728  [64000/80000]
# loss: 0.350313  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363255, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9467, device='cuda:0')
# precision of every test dataset class:  tensor(0.9468, device='cuda:0')
# auc: 0.9867719411849976
# Epoch 31
# -------------------------------
# loss: 0.384421  [    0/80000]
# loss: 0.336830  [12800/80000]
# loss: 0.348916  [25600/80000]
# loss: 0.381035  [38400/80000]
# loss: 0.326210  [51200/80000]
# loss: 0.358754  [64000/80000]
# loss: 0.349855  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363945, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9462, device='cuda:0')
# precision of every test dataset class:  tensor(0.9469, device='cuda:0')
# auc: 0.9867588877677917
# Epoch 32
# -------------------------------
# loss: 0.366596  [    0/80000]
# loss: 0.352593  [12800/80000]
# loss: 0.344441  [25600/80000]
# loss: 0.337069  [38400/80000]
# loss: 0.366599  [51200/80000]
# loss: 0.367260  [64000/80000]
# loss: 0.361968  [76800/80000]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.365398, torch metrics acc: 94.5%
#
# recall of every test dataset class:  tensor(0.9447, device='cuda:0')
# precision of every test dataset class:  tensor(0.9460, device='cuda:0')
# auc: 0.986567497253418
# Epoch 33
# -------------------------------
# loss: 0.370447  [    0/80000]
# loss: 0.345885  [12800/80000]
# loss: 0.353445  [25600/80000]
# loss: 0.366559  [38400/80000]
# loss: 0.370553  [51200/80000]
# loss: 0.360092  [64000/80000]
# loss: 0.382974  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.364824, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9461, device='cuda:0')
# precision of every test dataset class:  tensor(0.9460, device='cuda:0')
# auc: 0.9868446588516235
# Epoch 34
# -------------------------------
# loss: 0.380221  [    0/80000]
# loss: 0.350147  [12800/80000]
# loss: 0.346630  [25600/80000]
# loss: 0.348516  [38400/80000]
# loss: 0.362078  [51200/80000]
# loss: 0.365397  [64000/80000]
# loss: 0.364613  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362962, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9474, device='cuda:0')
# precision of every test dataset class:  tensor(0.9474, device='cuda:0')
# auc: 0.9869241714477539
# Epoch 35
# -------------------------------
# loss: 0.337716  [    0/80000]
# loss: 0.341738  [12800/80000]
# loss: 0.330652  [25600/80000]
# loss: 0.361317  [38400/80000]
# loss: 0.363750  [51200/80000]
# loss: 0.369733  [64000/80000]
# loss: 0.365053  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363661, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9472, device='cuda:0')
# precision of every test dataset class:  tensor(0.9475, device='cuda:0')
# auc: 0.9867664575576782
# Epoch 36
# -------------------------------
# loss: 0.378019  [    0/80000]
# loss: 0.355949  [12800/80000]
# loss: 0.377119  [25600/80000]
# loss: 0.351878  [38400/80000]
# loss: 0.352391  [51200/80000]
# loss: 0.353453  [64000/80000]
# loss: 0.379137  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363402, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9465, device='cuda:0')
# precision of every test dataset class:  tensor(0.9469, device='cuda:0')
# auc: 0.9869214296340942
# Epoch 37
# -------------------------------
# loss: 0.370874  [    0/80000]
# loss: 0.370347  [12800/80000]
# loss: 0.364927  [25600/80000]
# loss: 0.366133  [38400/80000]
# loss: 0.367286  [51200/80000]
# loss: 0.378896  [64000/80000]
# loss: 0.378794  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.364101, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9466, device='cuda:0')
# precision of every test dataset class:  tensor(0.9462, device='cuda:0')
# auc: 0.9868795871734619
# Epoch 38
# -------------------------------
# loss: 0.370784  [    0/80000]
# loss: 0.350171  [12800/80000]
# loss: 0.410313  [25600/80000]
# loss: 0.360288  [38400/80000]
# loss: 0.343836  [51200/80000]
# loss: 0.383637  [64000/80000]
# loss: 0.401991  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.364595, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9453, device='cuda:0')
# precision of every test dataset class:  tensor(0.9465, device='cuda:0')
# auc: 0.9868835210800171
# Epoch 39
# -------------------------------
# loss: 0.341399  [    0/80000]
# loss: 0.365736  [12800/80000]
# loss: 0.344197  [25600/80000]
# loss: 0.356374  [38400/80000]
# loss: 0.375085  [51200/80000]
# loss: 0.367140  [64000/80000]
# loss: 0.355709  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363337, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9474, device='cuda:0')
# precision of every test dataset class:  tensor(0.9472, device='cuda:0')
# auc: 0.9869341850280762
# Epoch 40
# -------------------------------
# loss: 0.359962  [    0/80000]
# loss: 0.343048  [12800/80000]
# loss: 0.359739  [25600/80000]
# loss: 0.370570  [38400/80000]
# loss: 0.370424  [51200/80000]
# loss: 0.352143  [64000/80000]
# loss: 0.367282  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.364186, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9470, device='cuda:0')
# precision of every test dataset class:  tensor(0.9464, device='cuda:0')
# auc: 0.9868425130844116
# Epoch 41
# -------------------------------
# loss: 0.354065  [    0/80000]
# loss: 0.335260  [12800/80000]
# loss: 0.358284  [25600/80000]
# loss: 0.349245  [38400/80000]
# loss: 0.334736  [51200/80000]
# loss: 0.379291  [64000/80000]
# loss: 0.384584  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363839, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9475, device='cuda:0')
# precision of every test dataset class:  tensor(0.9480, device='cuda:0')
# auc: 0.9869633913040161
# Epoch 42
# -------------------------------
# loss: 0.334155  [    0/80000]
# loss: 0.379157  [12800/80000]
# loss: 0.379303  [25600/80000]
# loss: 0.370107  [38400/80000]
# loss: 0.359729  [51200/80000]
# loss: 0.373259  [64000/80000]
# loss: 0.381826  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363388, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9474, device='cuda:0')
# precision of every test dataset class:  tensor(0.9470, device='cuda:0')
# auc: 0.9869221448898315
# Epoch 43
# -------------------------------
# loss: 0.350364  [    0/80000]
# loss: 0.358618  [12800/80000]
# loss: 0.388569  [25600/80000]
# loss: 0.356494  [38400/80000]
# loss: 0.361615  [51200/80000]
# loss: 0.377322  [64000/80000]
# loss: 0.350644  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.362804, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9471, device='cuda:0')
# precision of every test dataset class:  tensor(0.9474, device='cuda:0')
# auc: 0.9869217872619629
# Epoch 44
# -------------------------------
# loss: 0.361736  [    0/80000]
# loss: 0.373824  [12800/80000]
# loss: 0.345832  [25600/80000]
# loss: 0.366383  [38400/80000]
# loss: 0.354400  [51200/80000]
# loss: 0.325391  [64000/80000]
# loss: 0.352642  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.364829, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9454, device='cuda:0')
# precision of every test dataset class:  tensor(0.9470, device='cuda:0')
# auc: 0.986875057220459
# Epoch 45
# -------------------------------
# loss: 0.360278  [    0/80000]
# loss: 0.362878  [12800/80000]
# loss: 0.358247  [25600/80000]
# loss: 0.370633  [38400/80000]
# loss: 0.330213  [51200/80000]
# loss: 0.374620  [64000/80000]
# loss: 0.361615  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363565, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9472, device='cuda:0')
# precision of every test dataset class:  tensor(0.9476, device='cuda:0')
# auc: 0.9869567155838013
# Epoch 46
# -------------------------------
# loss: 0.365054  [    0/80000]
# loss: 0.337778  [12800/80000]
# loss: 0.376483  [25600/80000]
# loss: 0.344694  [38400/80000]
# loss: 0.373901  [51200/80000]
# loss: 0.375633  [64000/80000]
# loss: 0.378250  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363980, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9461, device='cuda:0')
# precision of every test dataset class:  tensor(0.9473, device='cuda:0')
# auc: 0.9869810342788696
# Epoch 47
# -------------------------------
# loss: 0.371836  [    0/80000]
# loss: 0.368882  [12800/80000]
# loss: 0.380738  [25600/80000]
# loss: 0.345149  [38400/80000]
# loss: 0.352743  [51200/80000]
# loss: 0.334059  [64000/80000]
# loss: 0.373576  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363431, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9483, device='cuda:0')
# precision of every test dataset class:  tensor(0.9480, device='cuda:0')
# auc: 0.9869269132614136
# Epoch 48
# -------------------------------
# loss: 0.339655  [    0/80000]
# loss: 0.382700  [12800/80000]
# loss: 0.368883  [25600/80000]
# loss: 0.347383  [38400/80000]
# loss: 0.346878  [51200/80000]
# loss: 0.358380  [64000/80000]
# loss: 0.361734  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363168, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9466, device='cuda:0')
# precision of every test dataset class:  tensor(0.9473, device='cuda:0')
# auc: 0.9868040680885315
# Epoch 49
# -------------------------------
# loss: 0.353999  [    0/80000]
# loss: 0.359230  [12800/80000]
# loss: 0.360846  [25600/80000]
# loss: 0.394949  [38400/80000]
# loss: 0.346346  [51200/80000]
# loss: 0.364399  [64000/80000]
# loss: 0.354259  [76800/80000]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.367421, torch metrics acc: 94.3%
#
# recall of every test dataset class:  tensor(0.9435, device='cuda:0')
# precision of every test dataset class:  tensor(0.9429, device='cuda:0')
# auc: 0.9869120121002197
# Epoch 50
# -------------------------------
# loss: 0.371027  [    0/80000]
# loss: 0.364292  [12800/80000]
# loss: 0.350931  [25600/80000]
# loss: 0.332833  [38400/80000]
# loss: 0.377976  [51200/80000]
# loss: 0.348741  [64000/80000]
# loss: 0.362173  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363405, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9467, device='cuda:0')
# precision of every test dataset class:  tensor(0.9480, device='cuda:0')
# auc: 0.9870554208755493
# Epoch 51
# -------------------------------
# loss: 0.357135  [    0/80000]
# loss: 0.346252  [12800/80000]
# loss: 0.372385  [25600/80000]
# loss: 0.358016  [38400/80000]
# loss: 0.334026  [51200/80000]
# loss: 0.335906  [64000/80000]
# loss: 0.360155  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363554, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9477, device='cuda:0')
# precision of every test dataset class:  tensor(0.9473, device='cuda:0')
# auc: 0.9870703816413879
# Epoch 52
# -------------------------------
# loss: 0.356955  [    0/80000]
# loss: 0.390456  [12800/80000]
# loss: 0.347556  [25600/80000]
# loss: 0.373419  [38400/80000]
# loss: 0.343367  [51200/80000]
# loss: 0.382115  [64000/80000]
# loss: 0.365029  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363326, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9477, device='cuda:0')
# precision of every test dataset class:  tensor(0.9477, device='cuda:0')
# auc: 0.9869279861450195
# Epoch 53
# -------------------------------
# loss: 0.341205  [    0/80000]
# loss: 0.381928  [12800/80000]
# loss: 0.368836  [25600/80000]
# loss: 0.340493  [38400/80000]
# loss: 0.363428  [51200/80000]
# loss: 0.354867  [64000/80000]
# loss: 0.336864  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362665, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9474, device='cuda:0')
# precision of every test dataset class:  tensor(0.9476, device='cuda:0')
# auc: 0.9868049621582031
# Epoch 54
# -------------------------------
# loss: 0.350902  [    0/80000]
# loss: 0.378952  [12800/80000]
# loss: 0.371963  [25600/80000]
# loss: 0.381505  [38400/80000]
# loss: 0.328172  [51200/80000]
# loss: 0.331219  [64000/80000]
# loss: 0.386207  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362779, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9480, device='cuda:0')
# precision of every test dataset class:  tensor(0.9475, device='cuda:0')
# auc: 0.9870184659957886
# Epoch 55
# -------------------------------
# loss: 0.389921  [    0/80000]
# loss: 0.373432  [12800/80000]
# loss: 0.352680  [25600/80000]
# loss: 0.348789  [38400/80000]
# loss: 0.358818  [51200/80000]
# loss: 0.380078  [64000/80000]
# loss: 0.404889  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.364880, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9475, device='cuda:0')
# precision of every test dataset class:  tensor(0.9475, device='cuda:0')
# auc: 0.9870042204856873
# Epoch 56
# -------------------------------
# loss: 0.398693  [    0/80000]
# loss: 0.331978  [12800/80000]
# loss: 0.344262  [25600/80000]
# loss: 0.338864  [38400/80000]
# loss: 0.358744  [51200/80000]
# loss: 0.316287  [64000/80000]
# loss: 0.371732  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362495, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9483, device='cuda:0')
# precision of every test dataset class:  tensor(0.9482, device='cuda:0')
# auc: 0.9870483875274658
# Epoch 57
# -------------------------------
# loss: 0.363741  [    0/80000]
# loss: 0.371477  [12800/80000]
# loss: 0.395064  [25600/80000]
# loss: 0.367625  [38400/80000]
# loss: 0.344308  [51200/80000]
# loss: 0.337711  [64000/80000]
# loss: 0.346776  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.365701, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9467, device='cuda:0')
# precision of every test dataset class:  tensor(0.9461, device='cuda:0')
# auc: 0.9869709610939026
# Epoch 58
# -------------------------------
# loss: 0.366072  [    0/80000]
# loss: 0.373390  [12800/80000]
# loss: 0.389140  [25600/80000]
# loss: 0.354881  [38400/80000]
# loss: 0.357451  [51200/80000]
# loss: 0.387755  [64000/80000]
# loss: 0.373975  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.365523, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9471, device='cuda:0')
# precision of every test dataset class:  tensor(0.9467, device='cuda:0')
# auc: 0.9869757890701294
# Epoch 59
# -------------------------------
# loss: 0.366923  [    0/80000]
# loss: 0.366111  [12800/80000]
# loss: 0.363508  [25600/80000]
# loss: 0.374748  [38400/80000]
# loss: 0.377275  [51200/80000]
# loss: 0.321146  [64000/80000]
# loss: 0.359910  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363521, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9482, device='cuda:0')
# precision of every test dataset class:  tensor(0.9478, device='cuda:0')
# auc: 0.9870046377182007
# Epoch 60
# -------------------------------
# loss: 0.332496  [    0/80000]
# loss: 0.365771  [12800/80000]
# loss: 0.374133  [25600/80000]
# loss: 0.351532  [38400/80000]
# loss: 0.356691  [51200/80000]
# loss: 0.338997  [64000/80000]
# loss: 0.361709  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.364690, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9472, device='cuda:0')
# precision of every test dataset class:  tensor(0.9468, device='cuda:0')
# auc: 0.9867988228797913
# Epoch 61
# -------------------------------
# loss: 0.348748  [    0/80000]
# loss: 0.362157  [12800/80000]
# loss: 0.367889  [25600/80000]
# loss: 0.356704  [38400/80000]
# loss: 0.356770  [51200/80000]
# loss: 0.361752  [64000/80000]
# loss: 0.353162  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363952, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9475, device='cuda:0')
# precision of every test dataset class:  tensor(0.9482, device='cuda:0')
# auc: 0.9871134161949158
# Epoch 62
# -------------------------------
# loss: 0.358615  [    0/80000]
# loss: 0.381660  [12800/80000]
# loss: 0.344949  [25600/80000]
# loss: 0.355626  [38400/80000]
# loss: 0.375241  [51200/80000]
# loss: 0.355957  [64000/80000]
# loss: 0.348524  [76800/80000]
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.372784, torch metrics acc: 93.9%
#
# recall of every test dataset class:  tensor(0.9377, device='cuda:0')
# precision of every test dataset class:  tensor(0.9429, device='cuda:0')
# auc: 0.986557126045227
# Epoch 63
# -------------------------------
# loss: 0.351754  [    0/80000]
# loss: 0.359205  [12800/80000]
# loss: 0.351494  [25600/80000]
# loss: 0.356869  [38400/80000]
# loss: 0.350069  [51200/80000]
# loss: 0.355104  [64000/80000]
# loss: 0.324569  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.362455, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9475, device='cuda:0')
# precision of every test dataset class:  tensor(0.9472, device='cuda:0')
# auc: 0.987080454826355
# Epoch 64
# -------------------------------
# loss: 0.360040  [    0/80000]
# loss: 0.363501  [12800/80000]
# loss: 0.358963  [25600/80000]
# loss: 0.359315  [38400/80000]
# loss: 0.352778  [51200/80000]
# loss: 0.335767  [64000/80000]
# loss: 0.337859  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.365829, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9448, device='cuda:0')
# precision of every test dataset class:  tensor(0.9470, device='cuda:0')
# auc: 0.9869464635848999
# Epoch 65
# -------------------------------
# loss: 0.371125  [    0/80000]
# loss: 0.351323  [12800/80000]
# loss: 0.396271  [25600/80000]
# loss: 0.349659  [38400/80000]
# loss: 0.365487  [51200/80000]
# loss: 0.374691  [64000/80000]
# loss: 0.366414  [76800/80000]
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.362857, torch metrics acc: 94.9%
#
# recall of every test dataset class:  tensor(0.9486, device='cuda:0')
# precision of every test dataset class:  tensor(0.9491, device='cuda:0')
# auc: 0.9870520830154419
# Epoch 66
# -------------------------------
# loss: 0.362275  [    0/80000]
# loss: 0.345386  [12800/80000]
# loss: 0.334999  [25600/80000]
# loss: 0.333640  [38400/80000]
# loss: 0.356298  [51200/80000]
# loss: 0.355291  [64000/80000]
# loss: 0.335839  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362032, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9482, device='cuda:0')
# precision of every test dataset class:  tensor(0.9482, device='cuda:0')
# auc: 0.9871898889541626
# Epoch 67
# -------------------------------
# loss: 0.324676  [    0/80000]
# loss: 0.399674  [12800/80000]
# loss: 0.379729  [25600/80000]
# loss: 0.376299  [38400/80000]
# loss: 0.359004  [51200/80000]
# loss: 0.375830  [64000/80000]
# loss: 0.372965  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363735, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9484, device='cuda:0')
# precision of every test dataset class:  tensor(0.9484, device='cuda:0')
# auc: 0.9869846105575562
# Epoch 68
# -------------------------------
# loss: 0.351251  [    0/80000]
# loss: 0.372651  [12800/80000]
# loss: 0.376062  [25600/80000]
# loss: 0.350445  [38400/80000]
# loss: 0.350562  [51200/80000]
# loss: 0.380291  [64000/80000]
# loss: 0.366224  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362895, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9474, device='cuda:0')
# precision of every test dataset class:  tensor(0.9489, device='cuda:0')
# auc: 0.9869567155838013
# Epoch 69
# -------------------------------
# loss: 0.336990  [    0/80000]
# loss: 0.360702  [12800/80000]
# loss: 0.333123  [25600/80000]
# loss: 0.348375  [38400/80000]
# loss: 0.360187  [51200/80000]
# loss: 0.367564  [64000/80000]
# loss: 0.342734  [76800/80000]
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.363217, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9468, device='cuda:0')
# precision of every test dataset class:  tensor(0.9464, device='cuda:0')
# auc: 0.9869070053100586
# Epoch 70
# -------------------------------
# loss: 0.347858  [    0/80000]
# loss: 0.359135  [12800/80000]
# loss: 0.368950  [25600/80000]
# loss: 0.358669  [38400/80000]
# loss: 0.366111  [51200/80000]
# loss: 0.362885  [64000/80000]
# loss: 0.350661  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363005, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9483, device='cuda:0')
# precision of every test dataset class:  tensor(0.9480, device='cuda:0')
# auc: 0.9872548580169678
# Epoch 71
# -------------------------------
# loss: 0.350459  [    0/80000]
# loss: 0.347809  [12800/80000]
# loss: 0.351046  [25600/80000]
# loss: 0.337582  [38400/80000]
# loss: 0.356394  [51200/80000]
# loss: 0.357698  [64000/80000]
# loss: 0.371682  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362652, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9476, device='cuda:0')
# precision of every test dataset class:  tensor(0.9483, device='cuda:0')
# auc: 0.9870787858963013
# Epoch 72
# -------------------------------
# loss: 0.375077  [    0/80000]
# loss: 0.356078  [12800/80000]
# loss: 0.346330  [25600/80000]
# loss: 0.358885  [38400/80000]
# loss: 0.350012  [51200/80000]
# loss: 0.373418  [64000/80000]
# loss: 0.377554  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362150, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9475, device='cuda:0')
# precision of every test dataset class:  tensor(0.9475, device='cuda:0')
# auc: 0.987128734588623
# Epoch 73
# -------------------------------
# loss: 0.369432  [    0/80000]
# loss: 0.356297  [12800/80000]
# loss: 0.347712  [25600/80000]
# loss: 0.349265  [38400/80000]
# loss: 0.383914  [51200/80000]
# loss: 0.368826  [64000/80000]
# loss: 0.350713  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362732, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9471, device='cuda:0')
# precision of every test dataset class:  tensor(0.9481, device='cuda:0')
# auc: 0.9870837330818176
# Epoch 74
# -------------------------------
# loss: 0.340456  [    0/80000]
# loss: 0.374303  [12800/80000]
# loss: 0.345369  [25600/80000]
# loss: 0.370133  [38400/80000]
# loss: 0.350548  [51200/80000]
# loss: 0.392606  [64000/80000]
# loss: 0.390131  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.363197, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9478, device='cuda:0')
# precision of every test dataset class:  tensor(0.9473, device='cuda:0')
# auc: 0.9870069026947021
# Epoch 75
# -------------------------------
# loss: 0.352270  [    0/80000]
# loss: 0.360034  [12800/80000]
# loss: 0.338474  [25600/80000]
# loss: 0.373834  [38400/80000]
# loss: 0.352606  [51200/80000]
# loss: 0.363311  [64000/80000]
# loss: 0.359083  [76800/80000]
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.365237, torch metrics acc: 94.6%
#
# recall of every test dataset class:  tensor(0.9468, device='cuda:0')
# precision of every test dataset class:  tensor(0.9461, device='cuda:0')
# auc: 0.987088680267334
# Epoch 76
# -------------------------------
# loss: 0.422986  [    0/80000]
# loss: 0.366838  [12800/80000]
# loss: 0.360274  [25600/80000]
# loss: 0.314623  [38400/80000]
# loss: 0.378145  [51200/80000]
# loss: 0.378379  [64000/80000]
# loss: 0.364427  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362785, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9476, device='cuda:0')
# precision of every test dataset class:  tensor(0.9480, device='cuda:0')
# auc: 0.9871126413345337
# Epoch 77
# -------------------------------
# loss: 0.367974  [    0/80000]
# loss: 0.378064  [12800/80000]
# loss: 0.366739  [25600/80000]
# loss: 0.339317  [38400/80000]
# loss: 0.367098  [51200/80000]
# loss: 0.354442  [64000/80000]
# loss: 0.371781  [76800/80000]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.362555, torch metrics acc: 94.8%
#
# recall of every test dataset class:  tensor(0.9473, device='cuda:0')
# precision of every test dataset class:  tensor(0.9480, device='cuda:0')
# auc: 0.9869108200073242
# early stop!
# Best Accuracy: 0.948900
#
# Done!
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.364835, torch metrics acc: 94.7%
#
# recall of every test dataset class:  tensor(0.9461, device='cuda:0')
# precision of every test dataset class:  tensor(0.9468, device='cuda:0')
# auc: 0.9849309921264648
# 0.9465
# 2023-03-30 16:57:38
